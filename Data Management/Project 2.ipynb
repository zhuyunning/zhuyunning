# %% [markdown]
# # Project 02 - Due Friday, November 11 at 12pm
#
# *Objectives*: Gain experience loading a transactional dataset into a relational database model you define yourself and using SQL to explore its contents. Transform the data into a star schema, documenting the schema visually, and explore the transformed data analytically by writing and executing a number of SQL queries using common syntax and functions and describing your findings.  Gain practice working on these tasks with a partner.
#
# *Grading criteria*: The tasks should all be completed, and questions should all be answered with SQL queries, diagrams, and charts in the space provided, unless a text answer is requested.  The notebook itself should be completely reproducible at datanotebook.org, from start to finish: another person should be able to use the same code to obtain the same results as yours.  Note that you will receive no more than partial credit if you do not add text/markdown cells explaining your thinking at each major step in each problem.
#
# *Attestation*: **Work in pairs**.  At the end of your submitted notebook, identify the work each partner performed and attest that each contributed substantially to the work.
#
# *Deadline*: Friday, November 11, 12pm.  One member of each pair must submit your notebook to Blackboard; you should not both submit it separately.  You may each push a copy to your own GitHub repository.
#
#
# ## Setup - select and obtain data
#
# The US City Open Data Census has a variety of [transactional data from all over the country](http://us-city.census.okfn.org/).  Select one topic and one city from this Census, download the data, and explain your reason for this choice before proceeding.  Provide a link to the web page for the data set you've chosen.
#
# I strongly encourage you to select a dataset from among the following topics:  Crime, Property Assessment, Campaign Finance Contributions, Service Requests (311), and Web Analytics.
#
# By *transactional* data I mean records at the grain of one event per business process.  In the case of Service Requests (311), for example, that would require data at the level of each individual report of a service request.  If this isn't clear, think about the bike trip data - each individual ride was included - and look for data at that level of event/process specificity.  Avoid data like the Connecticut boating data, which was summarized by year, not individual transactions.
#
# Please aim for a dataset of at least 10,000 individual records, but less than 250,000 records.  A little more or a little less is okay, but try to stay within these limits.

# %% [markdown]
# We chose data of crime in Baltimore: https://data.baltimorecity.gov/Public-Safety/BPD-Arrests/3i3v-ibrt

# %% [markdown]
# ### 1. Select one topic and one city from this Census

# %% [markdown]
# We select the crime topic and Baltimore, MD from this Census.

# %% [markdown]
# ### 2. Download the data

# %% [markdown]
# We download the csv file named as BPD_Arrests.

# %% [markdown]
# ### 3. Explain the reason for this choice before proceeing

# %% [markdown]
# First, we are interested in crime data, and Baltimore is kind of famous for its crime, so we choose the Baltimore as the city. Second, the database we download has many useful and insightful variables, like race, sex instance location and neighbourhood, which are convenient for us to dig into the data and maybe find out something interesting. Third, the dataset accords to the demands listed in the question. The database has 129836 records and it is transcational data.

# %% [markdown]
# ### 4. The link to the web page for the dataset

# %% [markdown]
# https://data.baltimorecity.gov/Public-Safety/BPD-Arrests/3i3v-ibrt

# %% [markdown]
# ## Problem 1 - examine the data (20 points)
#
# Use `csvstat`, `pandas`, or other tools as you see fit and observe the contents of your dataset.  Review important points from any metadata provided.  Describe what you see:  What do the columns mean?  Are there null values?  Which columns interest you the most?  Which columns present some opportunities, challenges, or questions you would like to ask?

# %%
# !mv BPD_Arrests.csv BPD.csv

# %%
# !wc -l BPD.csv
# Out:
# 129837 BPD.csv

# %%
# !csvcut -n BPD.csv
# Out:
#   1: Arrest
#   2: Age
#   3: Sex
#   4: Race
#   5: ArrestDate
#   6: ArrestTime
#   7: ArrestLocation
#   8: IncidentOffense
#   9: IncidentLocation
#  10: Charge
#  11: ChargeDescription
#  12: District
#  13: Post
#  14: Neighborhood
#  15: Location 1

# %%
# !csvstat BPD.csv
# Out:
#   1. Arrest
# 	<class 'int'>
# 	Nulls: True
# 	Min: 13610381
# 	Max: 16154217
# 	Sum: 1783148713031
# 	Mean: 14513545.494754234
# 	Median: 14118493
# 	Standard Deviation: 862754.9466899642
# 	Unique values: 122845
# 	5 most frequent values:
# 		16144428:	2
# 		16145794:	2
# 		16146910:	2
# 		14095005:	2
# 		16144347:	2
#   2. Age
# 	<class 'int'>
# 	Nulls: True
# 	Min: 0
# 	Max: 100
# 	Sum: 4280194
# 	Mean: 32.97326821151239
# 	Median: 30.0
# 	Standard Deviation: 11.593220356436293
# 	Unique values: 74
# 	5 most frequent values:
# 		22:	5982
# 		24:	5952
# 		23:	5933
# 		21:	5909
# 		25:	5489
#   3. Sex
# 	<class 'str'>
# 	Nulls: False
# 	Values: F, M
#   4. Race
# 	<class 'str'>
# 	Nulls: False
# 	Values: I, W, B, U, A
#   5. ArrestDate
# 	<class 'datetime.date'>
# 	Nulls: False
# 	Min: 2013-01-01
# 	Max: 2016-10-29
# 	Unique values: 1398
# 	5 most frequent values:
# 		2013-08-15:	186
# 		2014-01-09:	182
# 		2013-05-29:	178
# 		2014-04-23:	175
# 		2014-03-06:	172
#   6. ArrestTime
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 2312
# 	5 most frequent values:
# 		19:00:	2053
# 		18:00:	2018
# 		20:00:	2008
# 		11:00:	1981
# 		13:00:	1951
# 	Max length: 5
#   7. ArrestLocation
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 10221
# 	5 most frequent values:
# 		200 N EUTAW ST:	447
# 		1600 W NORTH AVE:	344
# 		400 E LEXINGTON ST:	297
# 		1500 RUSSELL ST:	295
# 		300 N EUTAW ST:	237
# 	Max length: 33
#   8. IncidentOffense
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 268
# 	5 most frequent values:
# 		Unknown Offense:	81377
# 		87-Narcotics:	12294
# 		4E-Common Assault:	6304
# 		UNKNOWN OFFENSE:	3209
# 		87O-Narcotics (Outside):	2602
# 	Max length: 28
#   9. IncidentLocation
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 15172
# 	5 most frequent values:
# 		200 N Eutaw St:	473
# 		400 W Lexington St:	240
# 		300 N Eutaw St:	235
# 		1500 Russell St:	222
# 		400 E Baltimore St:	221
# 	Max length: 34
#  10. Charge
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 585
# 	5 most frequent values:
# 		4 3550:	19010
# 		1 1415:	17977
# 		1 0077:	16147
# 		1 1635:	5255
# 		1 0573:	4230
# 	Max length: 6
#  11. ChargeDescription
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 11575
# 	5 most frequent values:
# 		Failure To Appear || Failure To Appear:	15373
# 		Asslt-Sec Degree || Assault-Sec Degree:	7769
# 		Unknown Charge:	7744
# 		Cds:Possess-Not Marihuana || Cds Violation:	5873
# 		Cds:Possess-Not Marihuana || Cds:	3760
# 	Max length: 54
#  12. District
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 9
# 	5 most frequent values:
# 		Southern:	11028
# 		Eastern:	10374
# 		Western:	10142
# 		Southeastern:	9793
# 		Northeastern:	8902
# 	Max length: 12
#  13. Post
# 	<class 'int'>
# 	Nulls: True
# 	Min: 111
# 	Max: 945
# 	Sum: 40739118
# 	Mean: 521.5942385250625
# 	Median: 516
# 	Standard Deviation: 270.2531288150249
# 	Unique values: 172
# 	5 most frequent values:
# 		733:	1802
# 		223:	1716
# 		224:	1641
# 		732:	1455
# 		111:	1254
#  14. Neighborhood
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 549
# 	5 most frequent values:
# 		DOWNTOWN:	2581
# 		SANDTOWN-WINCHESTER:	1708
# 		CARROLLTON RIDGE:	1572
# 		BROADWAY EAST:	1480
# 		PENN NORTH:	1442
# 	Max length: 33
#  15. Location 1
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 21215
# 	5 most frequent values:
# 		(39.2915696972, -76.6210983902):	401
# 		(0E-10, 0E-10):	399
# 		(39.3100495075, -76.6434028230):	322
# 		(39.2913120768, -76.6100972198):	300
# 		(39.2740805921, -76.6276929303):	221
# 	Max length: 31
#
# Row count: 129836

# %% [markdown]
# ### 1. What do the columns mean?

# %% [markdown]
# 1. Arrest: this is the id for every arrest to make sure each arrest is distinct and can be identifited.
# 2. Age: the age of criminal
# 3. Sex: the sex of criminal
# 4. Race: the race of criminal
# 5. ArrestDate: the date when the arrest happened
# 6. ArrestTime: the time when the arrest happened
# 7. ArrestLocation: the locatin where the arrest happened
# 8. Incidentoffense: whether there is an offense when the incident happened
# 9. IncidentLocation: the location where the incident happened
# 10. Charge : the charge id or serial number of the criminal
# 11. ChargeDescription: the description of the charge
# 12. District: the distric where the incident happened
# 13. Post: the post number where the incidnet happened
# 14. Neighborhood: the beighborhood where the incident happened
# 15. Location 1: the longitude and latitude where the incident happened

# %% [markdown]
# ### 2. Are there null values?

# %% [markdown]
# The variables listed below have null values:
#
# Arrest, Age, ArrestLocation, IncidentLocaiton, Charge, ChargeDescriptin, District, Post, Neighborhood and Location 1

# %% [markdown]
# ### 3. Which columns interest you the most?

# %% [markdown]
# Age, Sex and Race can give us a basic descrition of the criminal. If we dig into them, we might find a pattern of cirminals. Besides, the difference between IncidentLocation and ArrestLocation can tell us if the police officer is quickly and efficent enough to arrest criminals in the place where the incident happened. And if there are some other probabilities that lead to the differences between the IncidentLocation and ArrestLocation like the distance between incident location and police officer or nobody called the police about the incident, or the incident is too harmless to let witness to call police? Those questions can be figured out by using ChargeDescription and IncidentLocation and ArrestLocation. Also, we might find the patter that each crime happened frequency by using the Neighborhood and Distric dimensions.

# %% [markdown]
# ### 4. Which columns present some opportunities, challenges, or questions you would like to ask?

# %% [markdown]
# Opportunities: Through studying, we might find some patterns of criminals and some relationship between crime types and criminals. Also, we can study the change of crimes as the change of months.
#
#
# Challenges: there are a lot of variables have null values, but we have enough data, it may not be a big problem.
#
# Questions: which District and neighborhood are the places where the most crimes happened? Is there any realtionships  between criminals and crime types? Is there any differences between IncidentLocation and ArrestLocation. Is there any patterns of criminals?

# %% [markdown]
# ## Problem 2 - define a database model, load the data, and explore (20 points)
#
# Based on what you found above, create and connect to a new database, define a database table in it, and load this dataset into it.  You may use either of the methods for this step you have seen in earlier class notebooks.  You may choose to eliminate variables/columns if they are not relevant or interesting to you - explain your reasoning if you do.  Either way, you should load a majority of the columns present in the source dataset as it is in its raw form into the database, and all of its rows.
#
# Once your data has loaded successfully, run a `COUNT(*)` query to verify that all the data has loaded correctly.
#
# Explore the data to zero in on a few themes you would like to further study analytically.  Discuss columns that present opportunities for extraction into dimensions, and identify the specific columns that contain facts you want to measure.

# %% [markdown]
# ###  1. Create and connect to a new database

# %%
# %load_ext sql
# Out:
# /opt/conda/lib/python3.5/site-packages/IPython/config.py:13: ShimWarning: The `IPython.config` package has been deprecated. You should import from traitlets.config instead.
#   "You should import from traitlets.config instead.", ShimWarning)
# /opt/conda/lib/python3.5/site-packages/IPython/utils/traitlets.py:5: UserWarning: IPython.utils.traitlets has moved to a top-level traitlets package.
#   warn("IPython.utils.traitlets has moved to a top-level traitlets package.")

# %%
# !echo 'redspot' | sudo -S service postgresql restart
# Out:
# [sudo] password for jovyan: Restarting PostgreSQL 9.5 database server: main.

# %%
# !createdb -U dbuser BPD

# %%
# %sql postgresql://dbuser@localhost:5432/BPD
# Out:
# 'Connected: dbuser@BPD'

# %% [markdown]
#  ### 2. Define a database table in the database, and load this dataset into the database

# %%
# %%sql
# DROP TABLE IF EXISTS crime;
# CREATE TABLE crime (
#     arrest INTEGER,
#     age INTEGER,
#     sex CHAR(1),
#     race CHAR(1),
#     arrest_date TIMESTAMP,
#     arrest_time VARCHAR(5),
#     arrest_location VARCHAR(33),
#     incident_offence VARCHAR(28),
#     incident_location VARCHAR(34),
#     charge VARCHAR(6),
#     charge_description VARCHAR(54),
#     district VARCHAR(12),
#     post INTEGER,
#     neighborhood VARCHAR(33),
#     location1 VARCHAR(31)
# );
# Out:
# Done.
# Done.
# []

# %%
# !pwd
# Out:
# /home/jovyan/work

# %%
# %%sql
# COPY crime FROM '/home/jovyan/work/BPD.csv'
# CSV
# HEADER
# QUOTE '"'
# DELIMITER ',';
# Out:
# 129836 rows affected.
# []

# %% [markdown]
# ### 3. Run a COUNT(*) query to verify that all the data has loaded correctly

# %%
# %%sql
# SELECT COUNT(*) FROM crime;
# Out:
# 1 rows affected.
# [(129836,)]

# %% [markdown]
# ### 4. Handle null value

# %%
# %%sql
# UPDATE crime
# SET arrest = 0
# WHERE arrest IS NULL;
# Out:
# 6975 rows affected.
# []

# %%
# %%sql
# UPDATE crime
# SET age = 0
# WHERE age IS NULL;
# Out:
# 28 rows affected.
# []

# %%
# %%sql
# UPDATE crime
# SET arrest_location = 0
# WHERE arrest_location IS NULL;
# Out:
# 51722 rows affected.
# []

# %%
# %%sql
# UPDATE crime
# SET incident_location = 0
# WHERE incident_location IS NULL;
# Out:
# 53337 rows affected.
# []

# %%
# %%sql
# UPDATE crime
# SET charge = 0
# WHERE charge IS NULL;
# Out:
# 16357 rows affected.
# []

# %%
# %%sql
# UPDATE crime
# SET charge_description = 0
# WHERE charge_description IS NULL;
# Out:
# 502 rows affected.
# []

# %%
# %%sql
# UPDATE crime
# SET district = 0
# WHERE district IS NULL;
# Out:
# 51713 rows affected.
# []

# %%
# %%sql
# UPDATE crime
# SET post = 0
# WHERE post IS NULL;
# Out:
# 51731 rows affected.
# []

# %%
# %%sql
# UPDATE crime
# SET neighborhood = 0
# WHERE neighborhood IS NULL;
# Out:
# 51721 rows affected.
# []

# %%
# %%sql
# UPDATE crime
# SET location1 = 0
# WHERE location1 IS NULL;
# Out:
# 51251 rows affected.
# []

# %% [markdown]
# ### 5. Explore the data

# %% [markdown]
# #### a. Analyze sex

# %%
# %%sql
# SELECT sex, COUNT(sex)
# FROM crime
# GROUP BY sex;
# Out:
# 2 rows affected.
# [('F', 24699), ('M', 105137)]

# %% [markdown]
# #### There are fifth six of criminals are female, which are almost five time the number of female criminals
#
# #### b. Analyze race

# %%
# %%sql
# SELECT race, COUNT(race)
# FROM crime
# GROUP BY race;
# Out:
# 5 rows affected.
# [('I', 373), ('B', 105921), ('W', 20555), ('U', 2646), ('A', 341)]

# %%
# %matplotlib inline
result = _
result.bar()
# Out:
# /opt/conda/lib/python3.5/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# /opt/conda/lib/python3.5/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# <Container object of 5 artists>

# %% [markdown]
# #### As we can see in the picture, it is significant that race b has the largest frequency. White is the next.  The other three counts a little proportion.

# %% [markdown]
# #### c. Analyze arrest date

# %%
# %%sql
# SELECT arrest_date, count(arrest_date)
# FROM crime
# GROUP BY arrest_date
# ORDER BY COUNT(arrest_date) DESC
# LIMIT 10;
# Out:
# 10 rows affected.
# [(datetime.datetime(2013, 8, 15, 0, 0), 186),
#  (datetime.datetime(2014, 1, 9, 0, 0), 182),
#  (datetime.datetime(2013, 5, 29, 0, 0), 178),
#  (datetime.datetime(2014, 4, 23, 0, 0), 175),
#  (datetime.datetime(2014, 3, 6, 0, 0), 172),
#  (datetime.datetime(2014, 6, 5, 0, 0), 171),
#  (datetime.datetime(2013, 10, 1, 0, 0), 171),
#  (datetime.datetime(2015, 4, 27, 0, 0), 171),
#  (datetime.datetime(2013, 3, 13, 0, 0), 171),
#  (datetime.datetime(2014, 6, 11, 0, 0), 169)]

# %% [markdown]
# #### d. Transform date for future use

# %%
# %%sql
# SELECT DISTINCT TO_CHAR(arrest_date, 'YYYY-MM-DD') AS day_of_year,
#     TO_CHAR(arrest_date, 'YYYY') AS year,
#     TO_CHAR(arrest_date, 'MM') AS month,
#     TO_CHAR(arrest_date, 'DD') AS day,
#     TO_CHAR(arrest_date, 'Day') AS day_of_week_str,
#     TO_CHAR(arrest_date, 'D') AS day_of_week,
#     CASE WHEN CAST(TO_CHAR(arrest_date, 'D') AS INTEGER) >= 6
#         THEN 1
#         ELSE 0
#     END AS is_weekend,
#     CASE WHEN CAST(TO_CHAR(arrest_date, 'D') AS INTEGER) < 6
#         THEN 1
#         ELSE 0
#     END AS is_weekday,
#     TO_CHAR(arrest_date, 'HH24') AS hour_24,
#     TO_CHAR(arrest_date, 'Q') AS quarter
# FROM crime
# LIMIT 10;
# Out:
# 10 rows affected.
# [('2014-01-29', '2014', '01', '29', 'Wednesday', '4', 0, 1, '00', '1'),
#  ('2015-12-03', '2015', '12', '03', 'Thursday ', '5', 0, 1, '00', '4'),
#  ('2015-12-25', '2015', '12', '25', 'Friday   ', '6', 1, 0, '00', '4'),
#  ('2014-07-26', '2014', '07', '26', 'Saturday ', '7', 1, 0, '00', '3'),
#  ('2014-05-07', '2014', '05', '07', 'Wednesday', '4', 0, 1, '00', '2'),
#  ('2016-04-14', '2016', '04', '14', 'Thursday ', '5', 0, 1, '00', '2'),
#  ('2016-08-25', '2016', '08', '25', 'Thursday ', '5', 0, 1, '00', '3'),
#  ('2014-05-05', '2014', '05', '05', 'Monday   ', '2', 0, 1, '00', '2'),
#  ('2013-08-03', '2013', '08', '03', 'Saturday ', '7', 1, 0, '00', '3'),
#  ('2014-10-14', '2014', '10', '14', 'Tuesday  ', '3', 0, 1, '00', '4')]

# %%
# %%sql
# DROP TABLE IF EXISTS time;
# CREATE TABLE time (
#     year CHAR(4),
#     month CHAR(2),
#     day CHAR(2),
#     quarter CHAR(1)
# );
# Out:
# Done.
# Done.
# []

# %%
# %%sql
# INSERT INTO time (year, month, day, quarter)
# SELECT DISTINCT
#     TO_CHAR(arrest_date, 'YYYY') AS year,
#     TO_CHAR(arrest_date, 'MM') AS month,
#     TO_CHAR(arrest_date, 'DD') AS day,
#     TO_CHAR(arrest_date, 'Q') AS quarter
# FROM crime;
# Out:
# 1398 rows affected.
# []

# %%
# %%sql
# select * FROM time
# LIMIT 10;
# Out:
# 10 rows affected.
# [('2013', '08', '23', '3'),
#  ('2013', '12', '29', '4'),
#  ('2015', '04', '18', '2'),
#  ('2013', '07', '28', '3'),
#  ('2016', '06', '01', '2'),
#  ('2015', '02', '20', '1'),
#  ('2013', '01', '18', '1'),
#  ('2015', '09', '21', '3'),
#  ('2015', '08', '26', '3'),
#  ('2015', '07', '04', '3')]

# %% [markdown]
# #### e. Analyze the number of criminal arrest change from 2013 to 2015

# %%
# %%sql
# SELECT year, count(year)
# FROM time
# GROUP BY year
# ORDER BY COUNT(year) DESC;
# Out:
# 4 rows affected.
# [('2014', 365), ('2015', 365), ('2013', 365), ('2016', 303)]

# %%
# %matplotlib inline
result = _
result.bar()
# Out:
# <Container object of 4 artists>

# %% [markdown]
# #### As we can see from the picture, the number of arrested criminals is decreasing from 2013 to 2016.

# %% [markdown]
# #### f. See if there are some seasonal and monthly patterns of crimes

# %%
# %%sql
# SELECT month, count(month)
# FROM time
# GROUP BY month
# ORDER BY month;
# Out:
# 12 rows affected.
# [('01', 124),
#  ('02', 113),
#  ('03', 124),
#  ('04', 120),
#  ('05', 124),
#  ('06', 120),
#  ('07', 124),
#  ('08', 124),
#  ('09', 120),
#  ('10', 122),
#  ('11', 90),
#  ('12', 93)]

# %%
# %matplotlib inline
result = _
result.bar()
# Out:
# <Container object of 12 artists>

# %%
# %%sql
# SELECT quarter, COUNT(quarter)
# FROM time
# GROUP BY quarter
# ORDER BY quarter;
# Out:
# 4 rows affected.
# [('1', 361), ('2', 364), ('3', 368), ('4', 305)]

# %%
# %matplotlib inline
result = _
result.bar()
# Out:
# <Container object of 4 artists>

# %% [markdown]
# #### Clearly winter/quarter 4 has the least crimes.

# %% [markdown]
# #### g. Count numbers of all kinds of incident offences

# %%
# %%sql
# SELECT DISTINCT incident_offence, COUNT(incident_offence)
# FROM crime
# GROUP BY incident_offence
# ORDER BY COUNT(incident_offence) DESC
# LIMIT 10;
# Out:
# 10 rows affected.
# [('Unknown Offense', 81377),
#  ('87-Narcotics', 12294),
#  ('4E-Common Assault', 6304),
#  ('UNKNOWN OFFENSE', 3209),
#  ('87O-Narcotics (Outside)', 2602),
#  ('6C-Larceny- Shoplifting', 2222),
#  ('79-Other', 1959),
#  ('24-Towed Vehicle', 1581),
#  ('97-Search & Seizure', 1544),
#  ('4C-Agg. Asslt.- Oth.', 1466)]

# %% [markdown]
# #### h. Top 10 charge codes

# %%
# %%sql
# SELECT DISTINCT charge, COUNT(charge)
# FROM crime
# GROUP BY charge
# ORDER BY COUNT(charge) DESC
# LIMIT 10;
# Out:
# 10 rows affected.
# [('4 3550', 19010),
#  ('1 1415', 17977),
#  ('0', 16357),
#  ('1 0077', 16147),
#  ('1 1635', 5255),
#  ('1 0573', 4230),
#  ('3 0233', 4088),
#  ('1 0088', 3316),
#  ('2A0696', 2391),
#  ('1 1420', 2374)]

# %% [markdown]
# #### i. Top 10 charge descriptions

# %%
# %%sql
# SELECT DISTINCT charge_description, COUNT(charge_description)
# FROM crime
# GROUP BY charge_description
# ORDER BY COUNT(charge_description) DESC
# LIMIT 10;
# Out:
# 10 rows affected.
# [('Failure To Appear || Failure To Appear', 15373),
#  ('Asslt-Sec Degree || Assault-Sec Degree', 7769),
#  ('Unknown Charge', 7744),
#  ('Cds:Possess-Not Marihuana || Cds Violation', 5873),
#  ('Cds:Possess-Not Marihuana || Cds', 3760),
#  ('Violation Of Probation || Violation Of Probation', 3041),
#  ('Asslt-Sec Degree || Common Assault', 2805),
#  ('Cds: Poss Marihuana L/T 10 G || Cds Violation', 1633),
#  ('Asslt-Sec Degree || Assault', 1486),
#  ('Prostitution-General || Prostitution', 1431)]

# %% [markdown]
# #### j. Analyze top 10 charges and corresponding genders

# %%
# %%sql
# SELECT DISTINCT charge_description, sex, COUNT(sex)
# FROM crime
# GROUP BY charge_description, sex
# ORDER BY COUNT(sex) DESC
# LIMIT 10;
# Out:
# 10 rows affected.
# [('Failure To Appear || Failure To Appear', 'M', 11553),
#  ('Unknown Charge', 'M', 6681),
#  ('Asslt-Sec Degree || Assault-Sec Degree', 'M', 6202),
#  ('Cds:Possess-Not Marihuana || Cds Violation', 'M', 4890),
#  ('Failure To Appear || Failure To Appear', 'F', 3820),
#  ('Cds:Possess-Not Marihuana || Cds', 'M', 3092),
#  ('Violation Of Probation || Violation Of Probation', 'M', 2274),
#  ('Asslt-Sec Degree || Common Assault', 'M', 2135),
#  ('Asslt-Sec Degree || Assault-Sec Degree', 'F', 1567),
#  ('Cds: Poss Marihuana L/T 10 G || Cds Violation', 'M', 1442)]

# %% [markdown]
# #### k. Districts ranked by corresponding criminal numbers

# %%
# %%sql
# SELECT DISTINCT district, COUNT(*)
# FROM crime
# GROUP BY district
# ORDER BY COUNT(*) DESC;
# Out:
# 10 rows affected.
# [('0', 51713),
#  ('Southern', 11028),
#  ('Eastern', 10374),
#  ('Western', 10142),
#  ('Southeastern', 9793),
#  ('Northeastern', 8902),
#  ('Central', 8773),
#  ('Southwestern', 7059),
#  ('Northwestern', 6955),
#  ('Northern', 5097)]

# %% [markdown]
# #### Southern district has the most criminals.

# %% [markdown]
# #### l. Neighborhoods ranked by corresponding criminal numbers

# %%
# %%sql
# SELECT DISTINCT neighborhood,COUNT(*) AS Frequency
# FROM crime
# GROUP BY neighborhood
# ORDER BY Frequency DESC;
# Out:
# 550 rows affected.
# [('0', 51721),
#  ('DOWNTOWN', 2581),
#  ('SANDTOWN-WINCHESTER', 1708),
#  ('CARROLLTON RIDGE', 1572),
#  ('BROADWAY EAST', 1480),
#  ('PENN NORTH', 1442),
#  ('BROOKLYN', 1375),
#  ('Downtown', 1138),
#  ('UPTON', 1103),
#  ('BALTIMORE HIGHLANDS', 1094),
#  ('BELAIR-EDISON', 1056),
#  ('CENTRAL PARK HEIGHTS', 997),
#  ('COLDSTREAM HOMESTEAD MONTEBELLO', 954),
#  ('EAST BALTIMORE MIDWAY', 905),
#  ('Sandtown-Winchester', 823),
#  ('CHERRY HILL', 818),
#  ('WASHINGTON VILLAGE/PIGTOWN', 814),
#  ('MCELDERRY PARK', 784),
#  ('FRANKFORD', 722),
#  ('MONDAWMIN', 712),
#  ('Brooklyn', 673),
#  ('Broadway East', 665),
#  ('ELLWOOD PARK/MONUMENT', 595),
#  ('CURTIS BAY', 594),
#  ('OLIVER', 581),
#  ('HARLEM PARK', 553),
#  ('DUNBAR-BROADWAY', 541),
#  ('Belair-Edison', 527),
#  ('SHIPLEY HILL', 505),
#  ('FRANKLIN SQUARE', 496),
#  ('NEW SOUTHWEST/MOUNT CLARE', 496),
#  ('Carrollton Ridge', 491),
#  ('ARLINGTON', 481),
#  ('Central Park Heights', 481),
#  ('MADISON-EASTEND', 472),
#  ('FELLS POINT', 471),
#  ('PENROSE/FAYETTE STREET OUTREACH', 471),
#  ('East Baltimore Midway', 468),
#  ('Upton', 468),
#  ('Baltimore Highlands', 466),
#  ('Coldstream Homestead Montebel', 459),
#  ('DRUID HEIGHTS', 451),
#  ('WOODMERE', 450),
#  ('PATTERSON PARK NEIGHBORHOOD', 442),
#  ('HAMILTON HILLS', 440),
#  ('Penn North', 432),
#  ('BEREA', 431),
#  ('MILTON-MONTFORD', 430),
#  ('CARROLL - CAMDEN INDUSTRIAL AREA', 427),
#  ('WOODBOURNE-MCCABE', 425),
#  ('RESERVOIR HILL', 416),
#  ('Harlem Park', 413),
#  ('Cherry Hill', 409),
#  ('POPPLETON', 403),
#  ('McElderry Park', 398),
#  ('CHARLES NORTH', 396),
#  ('BOYD-BOOTH', 390),
#  ('PULASKI INDUSTRIAL AREA', 375),
#  ('Frankford', 355),
#  ('CARE', 352),
#  ('MILLHILL', 339),
#  ('Reservoir Hill', 331),
#  ('GAY STREET', 329),
#  ('Arlington', 322),
#  ('MIDTOWN-EDMONDSON', 312),
#  ('HIGHLANDTOWN', 304),
#  ('INNER HARBOR', 297),
#  ('OLDTOWN', 297),
#  ('Mondawmin', 294),
#  ("O'DONNELL HEIGHTS", 294),
#  ('WASHINGTON HILL', 292),
#  ('HOLLINS MARKET', 291),
#  ('WALBROOK', 281),
#  ('FRANKLINTOWN ROAD', 280),
#  ('Curtis Bay', 279),
#  ('IRVINGTON', 278),
#  ('Washington Village/Pigtown', 273),
#  ('LAKELAND', 270),
#  ('Milton-Montford', 267),
#  ('Oliver', 266),
#  ('BARCLAY', 263),
#  ('UNION SQUARE', 257),
#  ('PEN LUCY', 256),
#  ('PARKVIEW/WOODBROOK', 253),
#  ('BIDDLE STREET', 251),
#  ('GRACELAND PARK', 250),
#  ('BETTER WAVERLY', 242),
#  ('WESTPORT', 238),
#  ('JOHNSTON SQUARE', 237),
#  ('MIDDLE EAST', 235),
#  ('Woodmere', 232),
#  ('Berea', 223),
#  ('ALLENDALE', 220),
#  ('Poppleton', 217),
#  ('Patterson Park Neighborhood', 216),
#  ('REISTERSTOWN STATION', 216),
#  ('Ellwood Park/Monument', 213),
#  ('MORRELL PARK', 211),
#  ('WALTHERSON', 211),
#  ('NORTHWEST COMMUNITY ACTION', 205),
#  ('Madison-Eastend', 203),
#  ('CANTON', 202),
#  ('MOUNT HOLLY', 199),
#  ('Druid Heights', 195),
#  ('GLENHAM-BELHAR', 194),
#  ('MOSHER', 193),
#  ('FEDERAL HILL', 192),
#  ('OLD GOUCHER', 192),
#  ('ROSEMONT', 189),
#  ('Hamilton Hills', 188),
#  ('SOUTH CLIFTON PARK', 188),
#  ('New Southwest/Mount Clare', 185),
#  ('Gay Street', 183),
#  ('Penrose/Fayette Street Outrea', 183),
#  ('MOUNT VERNON', 179),
#  ('Fells Point', 177),
#  ('COPPIN HEIGHTS/ASH-CO-EAST', 175),
#  ('TOWANDA-GRANTLEY', 175),
#  ('HARWOOD', 173),
#  ('LOCH RAVEN', 173),
#  ('Dunbar-Broadway', 170),
#  ('HOWARD PARK', 170),
#  ('NORTH HARFORD ROAD', 170),
#  ('SAINT JOSEPHS', 170),
#  ('LANGSTON HUGHES', 169),
#  ('PENN-FALLSWAY', 169),
#  ('MID-TOWN BELVEDERE', 168),
#  ('HAMPDEN', 167),
#  ('PERKINS HOMES', 167),
#  ('PARK CIRCLE', 163),
#  ('EDMONDSON VILLAGE', 162),
#  ('WEST ARLINGTON', 159),
#  ('Midtown-Edmondson', 156),
#  ('Shipley Hill', 156),
#  ('MADISON PARK', 154),
#  ('FAIRFIELD AREA', 152),
#  ('UNIVERSITY OF MARYLAND', 149),
#  ('BROENING MANOR', 146),
#  ('DOLFIELD', 146),
#  ('Mosher', 145),
#  ('DARLEY PARK', 144),
#  ('ROSEMONT HOMEOWNERS/TENANTS', 144),
#  ('EDGEWOOD', 142),
#  ('Millhill', 140),
#  ('CHARLES VILLAGE', 139),
#  ('Mount Holly', 136),
#  ("O'Donnell Heights", 134),
#  ('Franklin Square', 133),
#  ('GREEKTOWN', 133),
#  ('BAYVIEW', 132),
#  ('Charles North', 131),
#  ('UPPER FELLS POINT', 131),
#  ('HOMELAND', 130),
#  ('GREENMOUNT WEST', 128),
#  ('Highlandtown', 127),
#  ('Coppin Heights/Ash-Co-East', 126),
#  ('EASTERWOOD', 125),
#  ('Inner Harbor', 125),
#  ('Barclay', 124),
#  ('Loch Raven', 124),
#  ('Hollins Market', 123),
#  ('EDNOR GARDENS-LAKESIDE', 122),
#  ('NEW NORTHWOOD', 122),
#  ('CARROLL-SOUTH HILTON', 121),
#  ('Clifton Park', 121),
#  ('Johnston Square', 121),
#  ('Pulaski Industrial Area', 121),
#  ('Franklintown Road', 120),
#  ('MID-GOVANS', 120),
#  ('Oldtown', 119),
#  ('JONESTOWN', 118),
#  ('MEDFORD', 118),
#  ('ROGNEL HEIGHTS', 118),
#  ('Woodbourne-McCabe', 117),
#  ('Middle East', 116),
#  ('WAVERLY', 116),
#  ('CANTON INDUSTRIAL AREA', 113),
#  ('SETON HILL', 111),
#  ('WESTFIELD', 111),
#  ('New Northwood', 110),
#  ('Walbrook', 109),
#  ('Park Circle', 108),
#  ('REMINGTON', 108),
#  ('Dolfield', 106),
#  ('RIVERSIDE', 106),
#  ('Better Waverly', 105),
#  ('Howard Park', 105),
#  ('LUCILLE PARK', 105),
#  ('University Of Maryland', 105),
#  ('BRIDGEVIEW/GREENLAWN', 103),
#  ('HILLEN', 103),
#  ('Madison Park', 103),
#  ('Allendale', 101),
#  ('Biddle Street', 101),
#  ('South Clifton Park', 101),
#  ('CLIFTON PARK', 100),
#  ('HANLON-LONGWOOD', 100),
#  ('Waltherson', 100),
#  ('CONCERNED CITIZENS OF FOREST PARK', 99),
#  ('BOLTON HILL', 98),
#  ('GREENSPRING', 98),
#  ('LIBERTY SQUARE', 98),
#  ('Lakeland', 98),
#  ('Rosemont', 98),
#  ('Irvington', 97),
#  ('ARCADIA', 96),
#  ('DORCHESTER', 95),
#  ('GLEN OAKS', 95),
#  ('Graceland Park', 95),
#  ('Greektown', 95),
#  ('SOUTH BALTIMORE', 95),
#  ('SHARP-LEADENHALL', 94),
#  ('GLEN', 93),
#  ('KRESSON', 93),
#  ('North Harford Road', 91),
#  ('PARKLANE', 90),
#  ('Washington Hill', 90),
#  ('ARMISTEAD GARDENS', 88),
#  ('LAURAVILLE', 88),
#  ('Broening Manor', 87),
#  ('VIOLETVILLE', 87),
#  ('BEECHFIELD', 86),
#  ('FOREST PARK', 86),
#  ('Reisterstown Station', 86),
#  ('Easterwood', 85),
#  ('Fairfield Area', 84),
#  ('PORT COVINGTON', 84),
#  ('Armistead Gardens', 83),
#  ('Canton', 81),
#  ('FRANKLINTOWN', 81),
#  ('Federal Hill', 80),
#  ('Greenmount West', 80),
#  ('ORANGEVILLE', 80),
#  ('CEDMONT', 79),
#  ('DOWNTOWN WEST', 79),
#  ('Old Goucher', 79),
#  ('Ednor Gardens-Lakeside', 78),
#  ('PARKSIDE', 78),
#  ('West Arlington', 78),
#  ('CARROLL PARK', 77),
#  ('Glen Oaks', 76),
#  ('Morrell Park', 76),
#  ('Perkins Homes', 76),
#  ('HOPKINS BAYVIEW', 75),
#  ('Liberty Square', 75),
#  ('Saint Josephs', 75),
#  ('Glenham-Belhar', 74),
#  ('PATTERSON PLACE', 73),
#  ('Pen Lucy', 73),
#  ('Boyd-Booth', 72),
#  ('Greenspring', 72),
#  ('HERITAGE CROSSING', 72),
#  ('HUNTING RIDGE', 72),
#  ('MIDDLE BRANCH/REEDBIRD PARKS', 72),
#  ('PLEASANT VIEW GARDENS', 72),
#  ('Penn-Fallsway', 72),
#  ('WILSON PARK', 72),
#  ('CENTRAL FOREST PARK', 71),
#  ('CYLBURN', 71),
#  ('Union Square', 71),
#  ('FOUR BY FOUR', 70),
#  ('GWYNNS FALLS', 70),
#  ('Rosemont Homeowners/Tenants', 70),
#  ('BREWERS HILL', 69),
#  ('Edgewood', 69),
#  ('Parkview/Woodbrook', 69),
#  ('Harwood', 68),
#  ('Mount Vernon', 67),
#  ('Northwest Community Action', 66),
#  ('Towanda-Grantley', 66),
#  ('Hampden', 65),
#  ('Langston Hughes', 65),
#  ('Lauraville', 65),
#  ('BELAIR-PARKSIDE', 64),
#  ('Dorchester', 64),
#  ('WINCHESTER', 64),
#  ('Lucille Park', 63),
#  ('Mid-Town Belvedere', 63),
#  ('Westport', 63),
#  ('Darley Park', 62),
#  ('GARWYN OAKS', 62),
#  ('PIMLICO GOOD NEIGHBORS', 62),
#  ('ROSEMONT EAST', 62),
#  ('YORK-HOMELAND', 62),
#  ('Seton Hill', 61),
#  ('Bridgeview/Greenlawn', 60),
#  ('Pimlico Good Neighbors', 60),
#  ('Jonestown', 59),
#  ('WEST FOREST PARK', 59),
#  ('WINSTON-GOVANS', 59),
#  ('ABELL', 58),
#  ('ORCHARD RIDGE', 57),
#  ('CEDONIA', 56),
#  ('Medford', 56),
#  ('WRENLANE', 56),
#  ('ASHBURTON', 55),
#  ('Carroll - Camden Industrial A', 55),
#  ('WAKEFIELD', 55),
#  ('Hanlon-Longwood', 54),
#  ('Rognel Heights', 52),
#  ('Charles Village', 51),
#  ('WEST HILLS', 51),
#  ('Westfield', 51),
#  ('CAMERON VILLAGE', 50),
#  ('Orchard Ridge', 50),
#  ('EAST ARLINGTON', 49),
#  ('FALLSTAFF', 48),
#  ('Edmondson Village', 47),
#  ('Hillen', 47),
#  ('KERNEWOOD', 47),
#  ('Kresson', 47),
#  ('Orangeville', 47),
#  ('STADIUM AREA', 47),
#  ('Arcadia', 46),
#  ("BUTCHER'S HILL", 46),
#  ('Downtown West', 46),
#  ('Remington', 46),
#  ('Coldstream Homestead Montebello', 45),
#  ('MEDFIELD', 45),
#  ('Homeland', 44),
#  ('MOUNT WINANS', 44),
#  ('South Baltimore', 44),
#  ('Bayview', 43),
#  ('CALLAWAY-GARRISON', 43),
#  ('OAKENSHAWE', 43),
#  ('Garwyn Oaks', 42),
#  ('Upper Fells Point', 42),
#  ('HERRING RUN PARK', 40),
#  ('Parklane', 40),
#  ('SETON BUSINESS PARK', 40),
#  ('Cedonia', 39),
#  ('EVERGREEN LAWN', 39),
#  ('HOES HEIGHTS', 39),
#  ('ORANGEVILLE INDUSTRIAL AREA', 39),
#  ('RICHNOR SPRINGS', 39),
#  ('STONEWOOD-PENTWOOD-WINSTON', 39),
#  ('Waverly', 39),
#  ('YALE HEIGHTS', 39),
#  ('Carroll - Camden Industrial Area', 38),
#  ('Carroll Park', 38),
#  ('GROVE PARK', 38),
#  ('Cylburn', 37),
#  ('IDLEWOOD', 37),
#  ('Sharp-Leadenhall', 37),
#  ('Concerned Citizens Of Forest', 36),
#  ('Four By Four', 36),
#  ('Heritage Crossing', 36),
#  ('LITTLE ITALY', 36),
#  ('MORGAN STATE UNIVERSITY', 36),
#  ('Middle Branch/Reedbird Parks', 36),
#  ('OTTERBEIN', 36),
#  ('Central Forest Park', 35),
#  ('Forest Park', 35),
#  ('GUILFORD', 35),
#  ('BURLEITH-LEIGHTON', 34),
#  ('Mid-Govans', 34),
#  ('Parkside', 34),
#  ('West Forest Park', 34),
#  ('Callaway-Garrison', 33),
#  ('Riverside', 33),
#  ('WESTGATE', 33),
#  ('WOODBERRY', 33),
#  ('Cameron Village', 32),
#  ('Glen', 32),
#  ('PERRING LOCH', 32),
#  ('RAMBLEWOOD', 32),
#  ('Woodbourne Heights', 32),
#  ('Bolton Hill', 31),
#  ('PATTERSON PARK', 31),
#  ('WOODBOURNE HEIGHTS', 31),
#  ('Carroll-South Hilton', 30),
#  ('PANWAY/BRADDISH AVENUE', 30),
#  ('SAINT HELENA', 30),
#  ('TREMONT', 30),
#  ('Ashburton', 29),
#  ('MAYFIELD', 29),
#  ('Seton Business Park', 29),
#  ('Abell', 28),
#  ('Port Covington', 28),
#  ('RADNOR-WINSTON', 28),
#  ('Stadium Area', 28),
#  ('Cedmont', 27),
#  ('Kernewood', 27),
#  ('LEVINDALE', 27),
#  ('MOUNT WASHINGTON', 27),
#  ('TEN HILLS', 27),
#  ('WILHELM PARK', 27),
#  ('DICKEYVILLE', 26),
#  ('EASTWOOD', 26),
#  ('Gwynns Falls', 26),
#  ('BARRE CIRCLE', 25),
#  ('Barre Circle', 25),
#  ('Beechfield', 25),
#  ('East Arlington', 25),
#  ('HAWKINS POINT', 25),
#  ('MONTEBELLO', 25),
#  ('ROLAND PARK', 25),
#  ('Belair-Parkside', 24),
#  ('Grove Park', 24),
#  ("RIDGELY'S DELIGHT", 24),
#  ('UPLANDS', 24),
#  ('Wrenlane', 24),
#  ('Brewers Hill', 23),
#  ('Franklintown', 23),
#  ('Winston-Govans', 23),
#  ('DRUID HILL PARK', 22),
#  ('KENILWORTH PARK', 22),
#  ('LOWER EDMONDSON VILLAGE', 22),
#  ('Rosemont East', 22),
#  ('Stonewood-Pentwood-Winston', 22),
#  ('Violetville', 22),
#  ('LOCUST POINT', 21),
#  ('Oakenshawe', 21),
#  ('Orangeville Industrial Area', 21),
#  ('Penrose/Fayette Street Outreach', 21),
#  ('Perring Loch', 21),
#  ('Winchester', 21),
#  ("Butcher's Hill", 20),
#  ('CHINQUAPIN PARK', 20),
#  ('COLDSPRING', 20),
#  ('LAKE WALKER', 20),
#  ('Morgan State University', 20),
#  ('NORTH ROLAND PARK/POPLAR HILL', 20),
#  ('Patterson Place', 20),
#  ('Ramblewood', 20),
#  ('SAINT AGNES', 20),
#  ('Tremont', 19),
#  ('WINDSOR HILLS', 19),
#  ('EVESHAM PARK', 18),
#  ('Evergreen Lawn', 18),
#  ('Idlewood', 18),
#  ('Kenilworth Park', 18),
#  ('Levindale', 18),
#  ('OVERLEA', 18),
#  ('West Hills', 18),
#  ('Westgate', 18),
#  ('Beverly Hills', 17),
#  ('Canton Industrial Area', 17),
#  ('Fallstaff', 17),
#  ('GWYNNS FALLS/LEAKIN PARK', 17),
#  ('LOCUST POINT INDUSTRIAL AREA', 17),
#  ('MORAVIA-WALTHER', 17),
#  ('ROSEBANK', 17),
#  ('SPRING GARDEN INDUSTRIAL AREA', 17),
#  ('BEVERLY HILLS', 16),
#  ('ORIGINAL NORTHWOOD', 16),
#  ('Little Italy', 15),
#  ('Saint Agnes', 15),
#  ('Wakefield', 15),
#  ('Windsor Hills', 15),
#  ('BELVEDERE', 14),
#  ('FAIRMONT', 14),
#  ('Herring Run Park', 14),
#  ('Hopkins Bayview', 14),
#  ('Mayfield', 14),
#  ('Pleasant View Gardens', 14),
#  ('Richnor Springs', 14),
#  ('CROSS KEYS', 13),
#  ('Hunting Ridge', 13),
#  ('JONES FALLS AREA', 13),
#  ('Otterbein', 13),
#  ('Panway/Braddish Avenue', 13),
#  ('Ten Hills', 13),
#  ('York-Homeland', 13),
#  ('Gwynns Falls/Leakin Park', 12),
#  ('Hawkins Point', 12),
#  ('Locust Point Industrial Area', 12),
#  ('Montebello', 12),
#  ('Original Northwood', 12),
#  ('Patterson Park', 12),
#  ('SAINT PAUL', 12),
#  ('Wilson Park', 12),
#  ('CHESWOLDE', 11),
#  ('LOWER HERRING RUN PARK', 11),
#  ('Mount Winans', 11),
#  ('Yale Heights', 11),
#  ('Guilford', 10),
#  ('Woodberry', 10),
#  ('GREENMOUNT CEMETERY', 9),
#  ('HOLABIRD INDUSTRIAL PARK', 9),
#  ('JOHNS HOPKINS HOMEWOOD', 9),
#  ('Lower Edmondson Village', 9),
#  ('OAKLEE', 9),
#  ('TUSCANY-CANTERBURY', 9),
#  ('Uplands', 9),
#  ('Burleith-Leighton', 8),
#  ('FOREST PARK GOLF COURSE', 8),
#  ('Forest Park Golf Course', 8),
#  ('Hoes Heights', 8),
#  ('Jones Falls Area', 8),
#  ('Locust Point', 8),
#  ('Mount Washington', 8),
#  ('PURNELL', 8),
#  ('Wilhelm Park', 8),
#  ('CROSS COUNTRY', 7),
#  ('Cedarcroft', 7),
#  ('Lake Walker', 7),
#  ('Medfield', 7),
#  ('Overlea', 7),
#  ('WYMAN PARK', 7),
#  ('Cheswolde', 6),
#  ('Coldspring', 6),
#  ('Dickeyville', 6),
#  ('Druid Hill Park', 6),
#  ('Fairmont', 6),
#  ('Moravia-Walther', 6),
#  ("Ridgely's Delight", 6),
#  ('CEDARCROFT', 5),
#  ('Chinquapin Park', 5),
#  ('EVERGREEN', 5),
#  ('Eastwood', 5),
#  ('Roland Park', 5),
#  ('SABINA-MATTFELDT', 5),
#  ('Saint Helena', 5),
#  ('Holabird Industrial Park', 4),
#  ('North Roland Park/Poplar Hill', 4),
#  ('Saint Paul', 4),
#  ('Cross Keys', 3),
#  ('Evesham Park', 3),
#  ('Greenmount Cemetery', 3),
#  ('LAKE EVESHAM', 3),
#  ('LOYOLA/NOTRE DAME', 3),
#  ('MT PLEASANT PARK', 3),
#  ('Oaklee', 3),
#  ('Radnor-Winston', 3),
#  ('Spring Garden Industrial Area', 3),
#  ('Belvedere', 2),
#  ('Concerned Citizens Of Forest Park', 2),
#  ('Evergreen', 2),
#  ('Keswick', 2),
#  ('Lake Evesham', 2),
#  ('Lower Herring Run Park', 2),
#  ('MORGAN PARK', 2),
#  ('Morgan Park', 2),
#  ('Mt Pleasant Park', 2),
#  ('Purnell', 2),
#  ('Rosebank', 2),
#  ('THE ORCHARDS', 2),
#  ('Taylor Heights', 2),
#  ('Tuscany-Canterbury', 2),
#  ('Villages Of Homeland', 2),
#  ('WYNDHURST', 2),
#  ('Cross Country', 1),
#  ('Curtis Bay Industrial Area', 1),
#  ('Johns Hopkins Homewood', 1),
#  ('KESWICK', 1),
#  ('Sabina-Mattfeldt', 1),
#  ('TAYLOR HEIGHTS', 1),
#  ('Wyman Park', 1),
#  ('Wyndhurst', 1)]

# %% [markdown]
# #### Seems downtown is the most dangerous neighborhood.

# %% [markdown]
# #### m. Posts ranked by corresponding criminal numbers

# %%
# %%sql
# SELECT DISTINCT post, COUNT(*)
# FROM crime
# GROUP BY post
# ORDER BY COUNT(*) DESC
# LIMIT 10;
# Out:
# 10 rows affected.
# [(0, 51731),
#  (733, 1802),
#  (223, 1716),
#  (224, 1641),
#  (732, 1455),
#  (111, 1254),
#  (212, 1231),
#  (221, 1194),
#  (113, 1140),
#  (911, 1132)]

# %% [markdown]
# #### n. Age and corresponding criminal numbers

# %%
# %%sql
# SELECT DISTINCT age, COUNT(*) AS Frequency
# FROM crime
# GROUP BY age
# ORDER BY age;
# Out:
# 74 rows affected.
# [(0, 58),
#  (14, 7),
#  (15, 13),
#  (16, 264),
#  (17, 302),
#  (18, 3973),
#  (19, 4785),
#  (20, 5160),
#  (21, 5909),
#  (22, 5982),
#  (23, 5933),
#  (24, 5952),
#  (25, 5489),
#  (26, 5469),
#  (27, 5054),
#  (28, 4727),
#  (29, 4374),
#  (30, 4097),
#  (31, 3812),
#  (32, 3520),
#  (33, 3308),
#  (34, 3139),
#  (35, 2798),
#  (36, 2635),
#  (37, 2359),
#  (38, 2241),
#  (39, 2010),
#  (40, 1925),
#  (41, 2147),
#  (42, 2228),
#  (43, 2161),
#  (44, 2205),
#  (45, 2228),
#  (46, 2190),
#  (47, 2229),
#  (48, 1998),
#  (49, 2057),
#  (50, 1958),
#  (51, 1867),
#  (52, 1709),
#  (53, 1578),
#  (54, 1388),
#  (55, 1213),
#  (56, 982),
#  (57, 817),
#  (58, 688),
#  (59, 546),
#  (60, 476),
#  (61, 405),
#  (62, 305),
#  (63, 272),
#  (64, 220),
#  (65, 166),
#  (66, 114),
#  (67, 82),
#  (68, 56),
#  (69, 50),
#  (70, 48),
#  (71, 32),
#  (72, 25),
#  (73, 22),
#  (74, 17),
#  (75, 13),
#  (76, 12),
#  (77, 11),
#  (78, 3),
#  (79, 8),
#  (80, 4),
#  (81, 3),
#  (82, 1),
#  (87, 4),
#  (89, 1),
#  (96, 1),
#  (100, 1)]

# %% [markdown]
# ## Problem 3 - define a star schema, and load your data into it (30 points)
#
# Define a star schema consisting of at least one fact table and at least two dimensions.  Transform your source data into the new fact table and dimensions.  Discuss your key modeling decisions.
#
# Document your star schema with a diagram.  There several tools available for this, such as Google Docs and Microsoft Visio.

# %% [markdown]
# ### 1. Create dimension tables

# %% [markdown]
# #### a. Create location dimension

# %%
# %%sql
# DROP TABLE IF EXISTS location;
# CREATE TABLE location (
#     location_key SERIAL,
#     arrestLocation VARCHAR(33),
#     incidentLocation VARCHAR(34),
#     Location1 VARCHAR(31),
#     CONSTRAINT pk_location_key PRIMARY KEY(location_key)
# );
# Out:
# Done.
# Done.
# []

# %%
# %%sql
# INSERT INTO location (arrestLocation, incidentLocation, Location1)
# SELECT DISTINCT arrest_location, incident_location, location1
# FROM crime;
# Out:
# 42030 rows affected.
# []

# %%
# %%sql
# SELECT * FROM location
# LIMIT 10;
# Out:
# 10 rows affected.
# [(1, '4100 FLEETWOOD AVE', '4100 Fleetwood Av', '(39.3558990425, -76.5310915803)'),
#  (2, '2600 WEGWORTH LN', '2600 Wegworth Ln', '(39.2545661886, -76.6453235863)'),
#  (3, '2500 BROOKFIELD AVE', '2500 Brookfield Av', '(39.3157914808, -76.6338801822)'),
#  (4, '0', '2800  Argonne Dr', '0'),
#  (5, '200 WASHBURN AVE', '200 Washburn Av', '(39.2360039184, -76.6090551413)'),
#  (6, '1900 LANCASTER ST', '1900 Lancaster St', '(39.2827167492, -76.5887838251)'),
#  (7, '5300 YORK RD', '5300 York Rd', '(39.3541688679, -76.6098149966)'),
#  (8, '3100 PULASKI HWY', '0', '(39.2954526608, -76.5734386579)'),
#  (9, '500 N EAST AVE', '500 N East Av', '(39.2976372589, -76.5721280507)'),
#  (10, '1200 SEMINOLE AVE', '1200 Seminole Av', '(39.3001389111, -76.6912177084)')]

# %% [markdown]
# #### b. Create charge dimension

# %%
# %%sql
# DROP TABLE IF EXISTS charge;
# CREATE TABLE charge (
#     charge_key SERIAL,
#     charge VARCHAR(6),
#     charge_description VARCHAR(54),
#     CONSTRAINT pk_charge_key PRIMARY KEY(charge_key)
# );
# Out:
# Done.
# Done.
# []

# %%
# %%sql
# INSERT INTO charge (charge, charge_description)
# SELECT DISTINCT charge, charge_description
# FROM crime;
# Out:
# 11975 rows affected.
# []

# %%
# %%sql
# SELECT * FROM charge
# LIMIT 10;
# Out:
# 10 rows affected.
# [(1, '1 1106', 'CDS VIOLATION'),
#  (2, '3 0233', 'POSS W INT COCAINE'),
#  (3, '2A3550', 'Att-Cds Manuf/Dist. || Hgv/ Cds'),
#  (4, '5 3550', 'Cds:Poss Para || Cds Possess'),
#  (5, '0', 'Fugitive From Kansas'),
#  (6, '1 4200', 'Alc. Bev./Intox:Endanger || Common Assault'),
#  (7, '3 4030', 'Mal Destr Prop Value + $500 || Attemp B&E'),
#  (8, '2C3550', 'Con-Cds Manuf/Dist. || Distribution'),
#  (9, '2A3550', 'Att-Cds Manuf/Dist. || Cds Violations'),
#  (10, '0', 'Ta 16 101 A')]

# %% [markdown]
# #### c. Create district dimension

# %%
# %%sql
# DROP TABLE IF EXISTS district;
# CREATE TABLE district (
#     district_key SERIAL,
#     district VARCHAR(12),
#     post INTEGER,
#     neighborhood VARCHAR(33),
#     CONSTRAINT pk_district_key PRIMARY KEY(district_key)
# );
# Out:
# Done.
# Done.
# []

# %%
# %%sql
# INSERT INTO district (district, post, neighborhood)
# SELECT DISTINCT district, post, neighborhood
# FROM crime;
# Out:
# 1424 rows affected.
# []

# %%
# %%sql
# SELECT * FROM district
# LIMIT 10;
# Out:
# 10 rows affected.
# [(1, 'Southern', 942, 'SPRING GARDEN INDUSTRIAL AREA'),
#  (2, 'Northern', 533, 'Hampden'),
#  (3, 'Southeastern', 232, 'Canton'),
#  (4, 'Southwestern', 814, 'FRANKLINTOWN ROAD'),
#  (5, 'Southwestern', 815, 'Lower Edmondson Village'),
#  (6, 'Northwestern', 611, 'DRUID HILL PARK'),
#  (7, 'Southeastern', 223, 'BALTIMORE HIGHLANDS'),
#  (8, 'Western', 736, 'PENN NORTH'),
#  (9, 'Southeastern', 233, 'MEDFORD'),
#  (10, 'Eastern', 322, 'GAY STREET')]

# %% [markdown]
# #### d. Create date dimension

# %%
# %%sql
# DROP TABLE IF EXISTS date;
# CREATE TABLE date (
#     date_key SERIAL,
#     year CHAR(4),
#     month CHAR(2),
#     day CHAR(2),
#     quarter CHAR(1),
#     hour CHAR(5),
#     CONSTRAINT pk_date_key PRIMARY KEY(date_key)
# );
# Out:
# Done.
# Done.
# []

# %%
# %%sql
# INSERT INTO date (year, month, day, quarter, hour)
# SELECT DISTINCT
#     TO_CHAR(arrest_date, 'YYYY') AS year,
#     TO_CHAR(arrest_date, 'MM') AS month,
#     TO_CHAR(arrest_date, 'DD') AS day,
#     TO_CHAR(arrest_date, 'Q') AS quarter,
#     arrest_time
# FROM crime;
# Out:
# 90388 rows affected.
# []

# %%
# %%sql
# SELECT * FROM date
# LIMIT 10;
# Out:
# 10 rows affected.
# [(1, '2016', '03', '03', '1', '10:00'),
#  (2, '2015', '05', '30', '2', '02:39'),
#  (3, '2015', '02', '05', '1', '02:00'),
#  (4, '2013', '12', '23', '4', '21:35'),
#  (5, '2015', '07', '12', '3', '19:45'),
#  (6, '2015', '08', '11', '3', '20:00'),
#  (7, '2014', '01', '12', '1', '17:20'),
#  (8, '2016', '09', '24', '3', '0.30 '),
#  (9, '2015', '04', '23', '2', '06:45'),
#  (10, '2015', '06', '29', '2', '19:00')]

# %% [markdown]
# ### 2. Create fact table

# %%
# %%sql
# DROP TABLE IF EXISTS criminal;
# CREATE TABLE criminal (
#     locationkey INTEGER,
#     chargekey INTEGER,
#     districtkey INTEGER,
#     datekey INTEGER,
#     arrest INTEGER,
#     age INTEGER,
#     sex CHAR(1),
#     race CHAR(1),
#     arrest_date TIMESTAMP,
#     arrest_time VARCHAR(5),
#     arrest_location VARCHAR(33),
#     incident_offence VARCHAR(28),
#     incident_location VARCHAR(34),
#     charge VARCHAR(6),
#     charge_description VARCHAR(54),
#     district VARCHAR(12),
#     post INTEGER,
#     neighborhood VARCHAR(33),
#     location1 VARCHAR(31),
#     FOREIGN KEY(locationkey) REFERENCES location(location_key),
#     FOREIGN KEY(chargekey) REFERENCES charge(charge_key),
#     FOREIGN KEY(districtkey) REFERENCES district(district_key),
#     FOREIGN KEY(datekey) REFERENCES date(date_key)
# );
# Out:
# Done.
# Done.
# []

# %%
# %%sql
# INSERT INTO criminal (arrest, age, sex, race, arrest_date, arrest_time, arrest_location, incident_offence, incident_location,
#                      charge, charge_description, district, post, neighborhood, location1)
# SELECT
#     arrest,
#     age,
#     sex,
#     race,
#     arrest_date,
#     arrest_time,
#     arrest_location,
#     incident_offence,
#     incident_location,
#     charge,
#     charge_description,
#     district,
#     post,
#     neighborhood,
#     location1
# FROM crime;
# Out:
# 129836 rows affected.
# []

# %%
# %%sql
# UPDATE criminal
# SET locationkey = location.location_key
# FROM location
# WHERE
# criminal.arrest_location = location.arrestLocation
# AND
# criminal.incident_location = location.incidentLocation
# AND
# criminal.location1 = location.Location1;
# Out:
# 129836 rows affected.
# []

# %%
# %%sql
# SELECT * FROM criminal
# LIMIT 10;
# Out:
# 10 rows affected.
# [(35859, None, None, None, 16139961, 37, 'M', 'B', datetime.datetime(2016, 9, 29, 0, 0), '21.00', '0', 'UNKNOWN OFFENSE', '0', '1 1415', 'ASSAULT-SEC DEGREE', '0', 0, '0', '0'),
#  (35859, None, None, None, 16133530, 59, 'F', 'B', datetime.datetime(2016, 9, 16, 0, 0), '11.25', '0', 'UNKNOWN OFFENSE', '0', '1 0077', 'FAILURE TO APPEAR', '0', 0, '0', '0'),
#  (35859, None, None, None, 16084915, 52, 'M', 'B', datetime.datetime(2016, 6, 11, 0, 0), '06:15', '0', 'Unknown Offense', '0', '0', 'Vop', '0', 0, '0', '0'),
#  (35859, None, None, None, 16063120, 51, 'M', 'B', datetime.datetime(2016, 4, 30, 0, 0), '00:30', '0', 'Unknown Offense', '0', '0', 'Detain Only', '0', 0, '0', '0'),
#  (35859, None, None, None, 16048494, 29, 'M', 'B', datetime.datetime(2016, 4, 4, 0, 0), '20:12', '0', 'Unknown Offense', '0', '0', 'Traffic', '0', 0, '0', '0'),
#  (35859, None, None, None, 16046159, 26, 'M', 'B', datetime.datetime(2016, 3, 30, 0, 0), '10:33', '0', 'Unknown Offense', '0', '0', 'Vop', '0', 0, '0', '0'),
#  (35859, None, None, None, 16012398, 38, 'M', 'B', datetime.datetime(2016, 1, 28, 0, 0), '00:18', '0', 'Unknown Offense', '0', '1 0990', '0', '0', 0, '0', '0'),
#  (35859, None, None, None, 15176072, 51, 'M', 'B', datetime.datetime(2015, 11, 22, 0, 0), '14:00', '0', 'Unknown Offense', '0', '0', 'Detain Only', '0', 0, '0', '0'),
#  (35859, None, None, None, 14034358, 44, 'M', 'B', datetime.datetime(2014, 3, 6, 0, 0), '13:00', '0', 'Unknown Offense', '0', '0', 'Urinate In Public', '0', 0, '0', '0'),
#  (35859, None, None, None, 15165802, 23, 'M', 'W', datetime.datetime(2015, 11, 3, 0, 0), '14:00', '0', 'Unknown Offense', '0', '1 1338', '0', '0', 0, '0', '0')]

# %%
# %%sql
# UPDATE criminal
# SET chargekey = charge.charge_key
# FROM charge
# WHERE
# criminal.charge = charge.charge
# AND
# criminal.charge_description = charge.charge_description;
# Out:
# 129836 rows affected.
# []

# %%
# %%sql
# SELECT * FROM criminal
# LIMIT 10;
# Out:
# 10 rows affected.
# [(35859, 4073, None, None, 15165802, 23, 'M', 'W', datetime.datetime(2015, 11, 3, 0, 0), '14:00', '0', 'Unknown Offense', '0', '1 1338', '0', '0', 0, '0', '0'),
#  (35859, 1687, None, None, 15159000, 29, 'M', 'B', datetime.datetime(2015, 10, 22, 0, 0), '00:30', '0', 'Unknown Offense', '0', '1 0990', '0', '0', 0, '0', '0'),
#  (35859, 4073, None, None, 15155335, 33, 'M', 'B', datetime.datetime(2015, 10, 15, 0, 0), '03:20', '0', 'Unknown Offense', '0', '1 1338', '0', '0', 0, '0', '0'),
#  (35859, 11443, None, None, 15136844, 32, 'M', 'B', datetime.datetime(2015, 9, 11, 0, 0), '00:50', '0', 'Unknown Offense', '0', '0', 'Driving Onsuspend Lic', '0', 0, '0', '0'),
#  (35859, 9593, None, None, 15122567, 20, 'M', 'B', datetime.datetime(2015, 8, 16, 0, 0), '02:30', '0', 'Unknown Offense', '0', '0', 'Federal Remand', '0', 0, '0', '0'),
#  (35859, 10625, None, None, 15101590, 33, 'F', 'W', datetime.datetime(2015, 7, 7, 0, 0), '14:00', '0', 'Unknown Offense', '0', '0', 'Detain Only', '0', 0, '0', '0'),
#  (35859, 10329, None, None, 15054572, 23, 'M', 'B', datetime.datetime(2015, 4, 8, 0, 0), '00:15', '0', 'Unknown Offense', '0', '0', 'Driving W/O Lic', '0', 0, '0', '0'),
#  (35859, 10625, None, None, 15053361, 22, 'F', 'B', datetime.datetime(2015, 4, 6, 0, 0), '14:00', '0', 'Unknown Offense', '0', '0', 'Detain Only', '0', 0, '0', '0'),
#  (35859, 2578, None, None, 15046179, 56, 'M', 'B', datetime.datetime(2015, 3, 25, 0, 0), '01:10', '0', 'Unknown Offense', '0', '0', 'Fto', '0', 0, '0', '0'),
#  (35859, 5913, None, None, 15044323, 18, 'M', 'B', datetime.datetime(2015, 3, 22, 0, 0), '11:00', '0', 'Unknown Offense', '0', '0', 'Maldest', '0', 0, '0', '0')]

# %%
# %%sql
# UPDATE criminal
# SET districtkey = district.district_key
# FROM district
# WHERE
# criminal.district = district.district
# AND
# criminal.post = district.post
# AND
# criminal.neighborhood = district.neighborhood;
# Out:
# 129836 rows affected.
# []

# %%
# %%sql
# SELECT * FROM criminal
# LIMIT 10;
# Out:
# 10 rows affected.
# [(35859, 2578, 41, None, 15046179, 56, 'M', 'B', datetime.datetime(2015, 3, 25, 0, 0), '01:10', '0', 'Unknown Offense', '0', '0', 'Fto', '0', 0, '0', '0'),
#  (35859, 5913, 41, None, 15044323, 18, 'M', 'B', datetime.datetime(2015, 3, 22, 0, 0), '11:00', '0', 'Unknown Offense', '0', '0', 'Maldest', '0', 0, '0', '0'),
#  (35859, 10625, 41, None, 15025716, 33, 'M', 'B', datetime.datetime(2015, 2, 17, 0, 0), '00:30', '0', 'Unknown Offense', '0', '0', 'Detain Only', '0', 0, '0', '0'),
#  (35859, 10425, 41, None, 14211011, 33, 'F', 'B', datetime.datetime(2014, 12, 18, 0, 0), '23:50', '0', 'Unknown Offense', '0', '0', 'Vop', '0', 0, '0', '0'),
#  (35859, 10625, 41, None, 14181097, 20, 'M', 'B', datetime.datetime(2014, 10, 27, 0, 0), '10:30', '0', 'Unknown Offense', '0', '0', 'Detain Only', '0', 0, '0', '0'),
#  (35859, 10625, 41, None, 14161631, 30, 'M', 'W', datetime.datetime(2014, 9, 23, 0, 0), '18:30', '0', 'Unknown Offense', '0', '0', 'Detain Only', '0', 0, '0', '0'),
#  (35859, 2036, 41, None, 0, 23, 'M', 'B', datetime.datetime(2015, 7, 14, 0, 0), '23:27', '0', 'Unknown Offense', '0', '0', 'Unknown Charge', '0', 0, '0', '0'),
#  (35859, 10625, 41, None, 14095425, 38, 'M', 'B', datetime.datetime(2014, 6, 11, 0, 0), '11:15', '0', 'Unknown Offense', '0', '0', 'Detain Only', '0', 0, '0', '0'),
#  (35859, 3035, 41, None, 14088273, 30, 'M', 'B', datetime.datetime(2014, 5, 31, 0, 0), '02:30', '0', 'Unknown Offense', '0', '0', 'Fta', '0', 0, '0', '0'),
#  (35859, 10625, 41, None, 14053953, 44, 'M', 'B', datetime.datetime(2014, 4, 7, 0, 0), '11:00', '0', 'Unknown Offense', '0', '0', 'Detain Only', '0', 0, '0', '0')]

# %%
# %%sql
# ALTER TABLE criminal
# ADD key SERIAL;
# Out:
# Done.
# []

# %%
# %%sql
# SELECT * FROM criminal
# LIMIT 10;
# Out:
# 10 rows affected.
# [(35859, 10625, 41, None, 14053953, 44, 'M', 'B', datetime.datetime(2014, 4, 7, 0, 0), '11:00', '0', 'Unknown Offense', '0', '0', 'Detain Only', '0', 0, '0', '0', 1),
#  (35859, 2036, 41, None, 0, 20, 'M', 'B', datetime.datetime(2015, 1, 27, 0, 0), '10:40', '0', 'Unknown Offense', '0', '0', 'Unknown Charge', '0', 0, '0', '0', 2),
#  (35859, 1945, 41, None, 14029790, 52, 'M', 'B', datetime.datetime(2014, 2, 26, 0, 0), '12:45', '0', 'Unknown Offense', '0', '0', 'Fugitive From Delaware', '0', 0, '0', '0', 3),
#  (35859, 6198, 41, None, 14015960, 21, 'F', 'B', datetime.datetime(2014, 1, 31, 0, 0), '20:00', '0', 'Unknown Offense', '0', '1 0023', 'Robbery || Robbery', '0', 0, '0', '0', 4),
#  (35859, 10625, 41, None, 14010173, 39, 'M', 'W', datetime.datetime(2014, 1, 22, 0, 0), '09:00', '0', 'Unknown Offense', '0', '0', 'Detain Only', '0', 0, '0', '0', 5),
#  (35859, 9593, 41, None, 13767146, 21, 'M', 'B', datetime.datetime(2013, 10, 14, 0, 0), '14:45', '0', 'Unknown Offense', '0', '0', 'Federal Remand', '0', 0, '0', '0', 6),
#  (35859, 2036, 41, None, 0, 47, 'F', 'W', datetime.datetime(2014, 10, 17, 0, 0), '11:00', '0', 'Unknown Offense', '0', '0', 'Unknown Charge', '0', 0, '0', '0', 7),
#  (35859, 11435, 41, None, 13732402, 29, 'F', 'W', datetime.datetime(2013, 8, 14, 0, 0), '12:39', '0', 'Unknown Offense', '0', '0', 'Dui', '0', 0, '0', '0', 8),
#  (35859, 3035, 41, None, 13668611, 24, 'M', 'B', datetime.datetime(2013, 4, 18, 0, 0), '01:20', '0', 'Unknown Offense', '0', '0', 'Fta', '0', 0, '0', '0', 9),
#  (35859, 2414, 41, None, 13656485, 45, 'F', 'B', datetime.datetime(2013, 3, 26, 0, 0), '16:30', '0', 'Unknown Offense', '0', '0', 'Fugitive', '0', 0, '0', '0', 10)]

# %%
# %%sql
# DROP TABLE IF EXISTS time;
# CREATE TABLE time (
#     key SERIAL,
#     year CHAR(4),
#     month CHAR(2),
#     day CHAR(2),
#     quarter CHAR(1),
#     hour CHAR(5)
# );
# Out:
# Done.
# Done.
# []

# %%
# %%sql
# INSERT INTO time (key, year, month, day, quarter, hour)
# SELECT
#     key,
#     TO_CHAR(arrest_date, 'YYYY') AS year,
#     TO_CHAR(arrest_date, 'MM') AS month,
#     TO_CHAR(arrest_date, 'DD') AS day,
#     TO_CHAR(arrest_date, 'Q') AS quarter,
#     arrest_time
# FROM criminal;
# Out:
# 129836 rows affected.
# []

# %%
# %%sql
# SELECT * FROM time
# LIMIT 10;
# Out:
# 10 rows affected.
# [(1, '2014', '04', '07', '2', '11:00'),
#  (2, '2015', '01', '27', '1', '10:40'),
#  (3, '2014', '02', '26', '1', '12:45'),
#  (4, '2014', '01', '31', '1', '20:00'),
#  (5, '2014', '01', '22', '1', '09:00'),
#  (6, '2013', '10', '14', '4', '14:45'),
#  (7, '2014', '10', '17', '4', '11:00'),
#  (8, '2013', '08', '14', '3', '12:39'),
#  (9, '2013', '04', '18', '2', '01:20'),
#  (10, '2013', '03', '26', '1', '16:30')]

# %%
# %%sql
# ALTER TABLE criminal
# ADD year CHAR (4),
# ADD month CHAR (2),
# ADD day CHAR(2),
# ADD quarter CHAR(1),
# ADD hour CHAR(5);
# Out:
# Done.
# []

# %%
# %%sql
# UPDATE criminal
# SET year = time.year,
#     month = time.month,
#     day = time.day,
#     quarter = time.quarter,
#     hour = time.hour
# FROM time
# WHERE
# criminal.key = time.key
# Out:
# 129836 rows affected.
# []

# %%
# %%sql
# SELECT * FROM criminal
# LIMIT 50;
# Out:
# 50 rows affected.
# [(33751, 2868, 41, None, 16147740, 24, 'M', 'B', datetime.datetime(2016, 10, 17, 0, 0), '13:15', '0', 'Unknown Offense', '0', '1 1415', 'ASSAULT-SEC DEGREE', '0', 0, '0', '(0E-10, 0E-10)', 881, '2016', '10', '17', '4', '13:15'),
#  (35859, 10134, 41, None, 14180627, 59, 'M', 'B', datetime.datetime(2014, 10, 25, 0, 0), '20:33', '0', 'Unknown Offense', '0', '0', 'Alc Bev/ Open Cont', '0', 0, '0', '0', 923, '2014', '10', '25', '4', '20:33'),
#  (35859, 7339, 41, None, 14062292, 28, 'M', 'B', datetime.datetime(2014, 4, 19, 0, 0), '14:00', '0', 'Unknown Offense', '0', '0', 'Bench Fto', '0', 0, '0', '0', 1107, '2014', '04', '19', '2', '14:00'),
#  (25847, 6190, 41, None, 15068936, 42, 'M', 'B', datetime.datetime(2015, 5, 3, 0, 0), '01:50', '0', 'Unknown Offense', '3400 Callaway Ave', '0', 'Curfew Violation', '0', 0, '0', '0', 1692, '2015', '05', '03', '2', '01:50'),
#  (35859, 8040, 41, None, 16113781, 23, 'M', 'B', datetime.datetime(2016, 8, 8, 0, 0), '22.45', '0', 'UNKNOWN OFFENSE', '0', '0', 'DIRTBIKE', '0', 0, '0', '0', 1816, '2016', '08', '08', '3', '22.45'),
#  (35859, 10529, 41, None, 15104660, 20, 'M', 'B', datetime.datetime(2015, 7, 13, 0, 0), '20:25', '0', 'Unknown Offense', '0', '0', 'Dirt Bike', '0', 0, '0', '0', 2755, '2015', '07', '13', '3', '20:25'),
#  (32124, 656, 41, None, 13734736, 21, 'M', 'B', datetime.datetime(2013, 8, 18, 0, 0), '17:20', '0', '79-Other', '3000 East Dr', '0', 'Dirt Bike Violation', '0', 0, '0', '0', 2802, '2013', '08', '18', '3', '17:20'),
#  (5840, 7702, 41, None, 16092015, 25, 'M', 'B', datetime.datetime(2016, 6, 24, 0, 0), '20:45', '0', 'Unknown Offense', '6200 Pulaski Hwy', '0', 'Dirtbike', '0', 0, '0', '0', 2933, '2016', '06', '24', '2', '20:45'),
#  (35859, 1224, 41, None, 15166274, 59, 'M', 'B', datetime.datetime(2015, 11, 4, 0, 0), '11:00', '0', 'Unknown Offense', '0', '0', 'Dispose Of Litter', '0', 0, '0', '0', 3064, '2015', '11', '04', '4', '11:00'),
#  (35859, 3675, 41, None, 14203590, 31, 'M', 'B', datetime.datetime(2014, 12, 7, 0, 0), '01:19', '0', 'Unknown Offense', '0', '0', 'Driving On Suspended', '0', 0, '0', '0', 3417, '2014', '12', '07', '4', '01:19'),
#  (35859, 2711, 41, None, 16008850, 46, 'M', 'B', datetime.datetime(2016, 1, 19, 0, 0), '00:41', '0', 'Unknown Offense', '0', '0', 'Driving Under The Influence Of', '0', 0, '0', '0', 3882, '2016', '01', '19', '1', '00:41'),
#  (35859, 10329, 41, None, 13682394, 50, 'M', 'B', datetime.datetime(2013, 5, 14, 0, 0), '01:20', '0', 'Unknown Offense', '0', '0', 'Driving W/O Lic', '0', 0, '0', '0', 3966, '2013', '05', '14', '2', '01:20'),
#  (3920, 5956, 41, None, 14004661, 22, 'M', 'B', datetime.datetime(2014, 1, 10, 0, 0), '03:40', '0', '88-Unfounded Call', '1500 Park Av', '0', 'Driving W/O License', '0', 0, '0', '0', 4058, '2014', '01', '10', '1', '03:40'),
#  (35859, 1921, 41, None, 16023132, 24, 'M', 'W', datetime.datetime(2016, 2, 17, 0, 0), '09:30', '0', 'Unknown Offense', '0', '0', 'Fail To Pay Fine', '0', 0, '0', '0', 4236, '2016', '02', '17', '1', '09:30'),
#  (35859, 9431, 41, None, 15186250, 27, 'M', 'B', datetime.datetime(2015, 12, 11, 0, 0), '18:58', '0', 'Unknown Offense', '0', '0', 'Driving Without A Licesne', '0', 0, '0', '0', 4342, '2015', '12', '11', '4', '18:58'),
#  (35859, 1921, 41, None, 16084931, 48, 'M', 'W', datetime.datetime(2016, 6, 11, 0, 0), '06:38', '0', 'Unknown Offense', '0', '0', 'Fail To Pay Fine', '0', 0, '0', '0', 4399, '2016', '06', '11', '2', '06:38'),
#  (35859, 11435, 41, None, 14074113, 25, 'M', 'W', datetime.datetime(2014, 5, 8, 0, 0), '01:18', '0', 'Unknown Offense', '0', '0', 'Dui', '0', 0, '0', '0', 4877, '2014', '05', '08', '2', '01:18'),
#  (35859, 8925, 41, None, 14126907, 57, 'M', 'B', datetime.datetime(2014, 7, 31, 0, 0), '16:00', '0', 'Unknown Offense', '0', '0', 'Failure To Pay Fine', '0', 0, '0', '0', 5675, '2014', '07', '31', '3', '16:00'),
#  (35859, 9178, 41, None, 13663295, 53, 'M', 'B', datetime.datetime(2013, 4, 8, 0, 0), '23:00', '0', 'Unknown Offense', '0', '0', 'Federal Detainee', '0', 0, '0', '0', 5775, '2013', '04', '08', '2', '23:00'),
#  (35859, 4648, 41, None, 16031967, 23, 'M', 'B', datetime.datetime(2016, 3, 5, 0, 0), '02:30', '0', 'Unknown Offense', '0', '0', 'Hit And Run', '0', 0, '0', '0', 7118, '2016', '03', '05', '1', '02:30'),
#  (37509, 9894, 41, None, 14079186, 25, 'M', 'B', datetime.datetime(2014, 5, 15, 0, 0), '11:30', '0', 'Unknown Offense', '3300 Liberty Hgts Av', '0', 'Loitering', '0', 0, '0', '0', 7211, '2014', '05', '15', '2', '11:30'),
#  (23661, 3447, 41, None, 13749226, 46, 'M', 'B', datetime.datetime(2013, 9, 12, 0, 0), '11:00', '0', 'Unknown Offense', '300 N Mlk Jr Bd', '0', 'Open Container', '0', 0, '0', '0', 7409, '2013', '09', '12', '3', '11:00'),
#  (35859, 8960, 41, None, 14108525, 40, 'F', 'W', datetime.datetime(2014, 7, 3, 0, 0), '00:00', '0', 'Unknown Offense', '0', '0', 'Prostitution', '0', 0, '0', '0', 7544, '2014', '07', '03', '3', '00:00'),
#  (35859, 2337, 41, None, 16081024, 28, 'F', 'B', datetime.datetime(2016, 6, 4, 0, 0), '18:25', '0', 'Unknown Offense', '0', '0', 'Pay Fine', '0', 0, '0', '0', 7641, '2016', '06', '04', '2', '18:25'),
#  (35859, 4934, 41, None, 13687318, 41, 'M', 'W', datetime.datetime(2013, 5, 22, 0, 0), '15:00', '0', 'Unknown Offense', '0', '0', 'Temp Fed Detainee', '0', 0, '0', '0', 7815, '2013', '05', '22', '2', '15:00'),
#  (2307, 9950, 41, None, 14021502, 59, 'M', 'B', datetime.datetime(2014, 2, 10, 0, 0), '13:00', '0', '71-Sex Offender Re', '600 E Fayette St', '0', 'Sex Off -Fail Notify/Incld', '0', 0, '0', '0', 7888, '2014', '02', '10', '1', '13:00'),
#  (35859, 10414, 41, None, 13632999, 28, 'M', 'W', datetime.datetime(2013, 2, 11, 0, 0), '12:15', '0', 'Unknown Offense', '0', '0', 'Suspended License', '0', 0, '0', '0', 7959, '2013', '02', '11', '1', '12:15'),
#  (35859, 2002, 41, None, 15058693, 43, 'M', 'B', datetime.datetime(2015, 4, 14, 0, 0), '14:00', '0', 'Unknown Offense', '0', '0', 'Temporary Federal Detainee', '0', 0, '0', '0', 8124, '2015', '04', '14', '2', '14:00'),
#  (35859, 3042, 41, None, 0, 64, 'M', 'W', datetime.datetime(2016, 8, 6, 0, 0), '12.00', '0', 'UNKNOWN OFFENSE', '0', '0', 'UNKNOWN CHARGE', '0', 0, '0', '0', 8382, '2016', '08', '06', '3', '12.00'),
#  (35859, 2036, 41, None, 0, 34, 'M', 'B', datetime.datetime(2015, 9, 22, 0, 0), '23:47', '0', 'Unknown Offense', '0', '0', 'Unknown Charge', '0', 0, '0', '0', 9250, '2015', '09', '22', '3', '23:47'),
#  (35859, 2036, 41, None, 0, 19, 'M', 'B', datetime.datetime(2014, 11, 14, 0, 0), '02:00', '0', 'Unknown Offense', '0', '0', 'Unknown Charge', '0', 0, '0', '0', 10633, '2014', '11', '14', '4', '02:00'),
#  (35859, 2036, 41, None, 0, 30, 'M', 'B', datetime.datetime(2014, 11, 12, 0, 0), '09:00', '0', 'Unknown Offense', '0', '0', 'Unknown Charge', '0', 0, '0', '0', 10718, '2014', '11', '12', '4', '09:00'),
#  (35859, 2036, 41, None, 0, 21, 'F', 'B', datetime.datetime(2014, 9, 4, 0, 0), '09:30', '0', 'Unknown Offense', '0', '0', 'Unknown Charge', '0', 0, '0', '0', 12175, '2014', '09', '04', '3', '09:30'),
#  (35859, 2036, 41, None, 0, 33, 'M', 'B', datetime.datetime(2015, 2, 24, 0, 0), '13:15', '0', 'Unknown Offense', '0', '0', 'Unknown Charge', '0', 0, '0', '0', 12469, '2015', '02', '24', '1', '13:15'),
#  (35859, 2036, 41, None, 0, 20, 'M', 'B', datetime.datetime(2014, 5, 17, 0, 0), '23:45', '0', 'Unknown Offense', '0', '0', 'Unknown Charge', '0', 0, '0', '0', 12713, '2014', '05', '17', '2', '23:45'),
#  (15400, 618, 41, None, 13617417, 47, 'M', 'B', datetime.datetime(2013, 1, 13, 0, 0), '19:00', '0', '79-Other', '1700 E 30Th St', '1 0043', 'Obstructing & Hindering || Failure To Obey', '0', 0, '0', '0', 16638, '2013', '01', '13', '1', '19:00'),
#  (35859, 1687, 41, None, 15189766, 34, 'M', 'B', datetime.datetime(2015, 12, 18, 0, 0), '13:15', '0', 'Unknown Offense', '0', '1 0990', '0', '0', 0, '0', '0', 18185, '2015', '12', '18', '4', '13:15'),
#  (35859, 1687, 41, None, 15192183, 51, 'M', 'W', datetime.datetime(2015, 12, 23, 0, 0), '09:00', '0', 'Unknown Offense', '0', '1 0990', '0', '0', 0, '0', '0', 19113, '2015', '12', '23', '4', '09:00'),
#  (35859, 1687, 41, None, 16027930, 16, 'M', 'B', datetime.datetime(2016, 2, 25, 0, 0), '15:00', '0', 'Unknown Offense', '0', '1 0990', '0', '0', 0, '0', '0', 20199, '2016', '02', '25', '1', '15:00'),
#  (35859, 1687, 41, None, 16039661, 31, 'M', 'B', datetime.datetime(2016, 3, 18, 0, 0), '00:01', '0', 'Unknown Offense', '0', '1 0990', '0', '0', 0, '0', '0', 20869, '2016', '03', '18', '1', '00:01'),
#  (35859, 1687, 41, None, 14031755, 35, 'M', 'B', datetime.datetime(2014, 3, 1, 0, 0), '19:15', '0', 'Unknown Offense', '0', '1 0990', '0', '0', 0, '0', '0', 25816, '2014', '03', '01', '1', '19:15'),
#  (35859, 1687, 41, None, 13775750, 24, 'F', 'B', datetime.datetime(2013, 10, 29, 0, 0), '21:15', '0', 'Unknown Offense', '0', '1 0990', '0', '0', 0, '0', '0', 26126, '2013', '10', '29', '4', '21:15'),
#  (35859, 1687, 41, None, 15118848, 26, 'M', 'B', datetime.datetime(2015, 8, 10, 0, 0), '03:10', '0', 'Unknown Offense', '0', '1 0990', '0', '0', 0, '0', '0', 26793, '2015', '08', '10', '3', '03:10'),
#  (35859, 1687, 41, None, 14065157, 31, 'M', 'B', datetime.datetime(2014, 4, 23, 0, 0), '22:00', '0', 'Unknown Offense', '0', '1 0990', '0', '0', 0, '0', '0', 27101, '2014', '04', '23', '2', '22:00'),
#  (35859, 1687, 41, None, 16098325, 26, 'M', 'B', datetime.datetime(2016, 7, 7, 0, 0), '23:00', '0', 'Unknown Offense', '0', '1 0990', '0', '0', 0, '0', '0', 27359, '2016', '07', '07', '3', '23:00'),
#  (35859, 1687, 41, None, 15033835, 26, 'M', 'B', datetime.datetime(2015, 3, 3, 0, 0), '14:30', '0', 'Unknown Offense', '0', '1 0990', '0', '0', 0, '0', '0', 28190, '2015', '03', '03', '1', '14:30'),
#  (35859, 2868, 41, None, 16124242, 29, 'M', 'B', datetime.datetime(2016, 8, 29, 0, 0), '18.30', '0', 'UNKNOWN OFFENSE', '0', '1 1415', 'ASSAULT-SEC DEGREE', '0', 0, '0', '0', 36017, '2016', '08', '29', '3', '18.30'),
#  (35859, 2868, 41, None, 16142831, 25, 'F', 'W', datetime.datetime(2016, 10, 6, 0, 0), '10:30', '0', 'Unknown Offense', '0', '1 1415', 'ASSAULT-SEC DEGREE', '0', 0, '0', '0', 36214, '2016', '10', '06', '4', '10:30'),
#  (35859, 2868, 41, None, 16130038, 21, 'M', 'B', datetime.datetime(2016, 9, 10, 0, 0), '2.40', '0', 'UNKNOWN OFFENSE', '0', '1 1415', 'ASSAULT-SEC DEGREE', '0', 0, '0', '0', 36264, '2016', '09', '10', '3', '2.40 '),
#  (35859, 2868, 41, None, 16109972, 31, 'M', 'B', datetime.datetime(2016, 8, 1, 0, 0), '12.20', '0', 'UNKNOWN OFFENSE', '0', '1 1415', 'ASSAULT-SEC DEGREE', '0', 0, '0', '0', 36314, '2016', '08', '01', '3', '12.20')]

# %%
# %%sql
# UPDATE criminal
# SET datekey = date.date_key
# FROM date
# WHERE
# criminal.year = date.year
# AND
# criminal.month = date.month
# AND
# criminal.day = date.day
# AND
# criminal.quarter = date.quarter
# AND
# criminal.hour = date.hour;
# Out:
# 129836 rows affected.
# []

# %%
# %%sql
# SELECT * FROM criminal
# LIMIT 10;
# Out:
# 10 rows affected.
# [(35859, 2868, 41, 27925, 16142831, 25, 'F', 'W', datetime.datetime(2016, 10, 6, 0, 0), '10:30', '0', 'Unknown Offense', '0', '1 1415', 'ASSAULT-SEC DEGREE', '0', 0, '0', '0', 36214, '2016', '10', '06', '4', '10:30'),
#  (35859, 2868, 41, 87189, 16130038, 21, 'M', 'B', datetime.datetime(2016, 9, 10, 0, 0), '2.40', '0', 'UNKNOWN OFFENSE', '0', '1 1415', 'ASSAULT-SEC DEGREE', '0', 0, '0', '0', 36264, '2016', '09', '10', '3', '2.40 '),
#  (35859, 2868, 41, 7233, 16109972, 31, 'M', 'B', datetime.datetime(2016, 8, 1, 0, 0), '12.20', '0', 'UNKNOWN OFFENSE', '0', '1 1415', 'ASSAULT-SEC DEGREE', '0', 0, '0', '0', 36314, '2016', '08', '01', '3', '12.20'),
#  (35859, 8846, 41, 34606, 16024257, 18, 'M', 'B', datetime.datetime(2016, 2, 18, 0, 0), '20:47', '0', 'Unknown Offense', '0', '1 0175', 'Handgun In Vehicle || Handgun In Vehicle', '0', 0, '0', '0', 36668, '2016', '02', '18', '1', '20:47'),
#  (35859, 11797, 41, 49958, 13711774, 23, 'M', 'B', datetime.datetime(2013, 7, 8, 0, 0), '21:30', '0', 'Unknown Offense', '0', '1 0233', 'Cds Poss W/Int To Dist || Cds Poss W/Int To Dist', '0', 0, '0', '0', 37530, '2013', '07', '08', '3', '21:30'),
#  (38275, 6208, 41, 1843, 13622640, 30, 'M', 'W', datetime.datetime(2013, 1, 22, 0, 0), '21:30', '0', '97-Search & Seizure', 'I 83N & Falls Rd', '1 0233', 'Cds Poss W/Int To Dist || Cds Violation', '0', 0, '0', '0', 37733, '2013', '01', '22', '1', '21:30'),
#  (10447, 3369, 41, 89412, 14052056, 20, 'M', 'B', datetime.datetime(2014, 4, 3, 0, 0), '18:15', '0', 'Unknown Offense', '1400 E Hoffman St', '1 0233', 'Cds Poss W/Int To Dist || Poss Cds', '0', 0, '0', '0', 37894, '2014', '04', '03', '2', '18:15'),
#  (35859, 644, 41, 38248, 13790216, 40, 'M', 'B', datetime.datetime(2013, 11, 28, 0, 0), '12:00', '0', 'Unknown Offense', '0', '1 0248', 'Cds:Obtain By Fraud || Cds:Obtain By Fraud', '0', 0, '0', '0', 38097, '2013', '11', '28', '4', '12:00'),
#  (35859, 11750, 41, 84892, 16055775, 21, 'M', 'W', datetime.datetime(2016, 4, 16, 0, 0), '10:00', '0', 'Unknown Offense', '0', '1 0349', 'Alc Bev./Retail Area Drink || Assault', '0', 0, '0', '0', 38472, '2016', '04', '16', '2', '10:00'),
#  (35859, 2419, 41, 63865, 16116024, 24, 'M', 'B', datetime.datetime(2016, 8, 11, 0, 0), '22.00', '0', 'UNKNOWN OFFENSE', '0', '1 0487', 'CDS: DISTR ETC. W/FIREARM', '0', 0, '0', '0', 38638, '2016', '08', '11', '3', '22.00')]

# %%
# %%sql
# ALTER TABLE criminal
# DROP arrest,
# DROP arrest_date,
# DROP arrest_time,
# DROP arrest_location,
# DROP incident_offence,
# DROP incident_location,
# DROP charge,
# DROP charge_description,
# DROP district,
# DROP post,
# DROP neighborhood,
# DROP location1,
# DROP key,
# DROP year,
# DROP month,
# DROP day,
# DROP quarter,
# DROP hour;
# Out:
# Done.
# []

# %%
# %%sql
# SELECT * FROM criminal
# LIMIT 10;
# Out:
# 10 rows affected.
# [(35859, 2419, 41, 63865, 24, 'M', 'B'),
#  (35859, 1423, 41, 82068, 27, 'M', 'B'),
#  (18933, 2839, 41, 38860, 31, 'M', 'B'),
#  (4049, 9435, 41, 6875, 24, 'M', 'B'),
#  (10247, 9435, 41, 35819, 25, 'M', 'B'),
#  (35859, 6089, 41, 46254, 32, 'M', 'B'),
#  (35859, 9051, 41, 31923, 44, 'M', 'B'),
#  (35859, 9051, 41, 49913, 19, 'M', 'B'),
#  (35859, 7206, 41, 33458, 25, 'M', 'B'),
#  (9883, 5232, 1065, 58234, 24, 'M', 'B')]

# %%
from IPython.display import Image
Image(url = "https://raw.githubusercontent.com/gwsb-istm-6212-fall-2016/JingningLi/master/diagram.jpg", width=1000, height=1000)
# Out:
# <img src="https://raw.githubusercontent.com/gwsb-istm-6212-fall-2016/JingningLi/master/diagram.jpg" width="1000" height="1000"/>

# %% [markdown]
# We create four dimension tables and one fact table. Four dimension tables are location, cahrge, district and date. One fact table is criminal. All four dimension tables have their own surrogate keys which are location_key, charge_key, district_key and date_key. All four surrogate keys are primary keys in their own dimension tables. And all four of them are included in the fact table, which have been referenced as foreign keys. We include age, sex and race in our fact table. All three of them are kinds of factless fact, because they are not typical facts to measure a process. So our fact table are actually factless fact table.

# %% [markdown]
# ## Problem 4 - explore your data in its new schema (30 points)
#
# Strictly using the dimensional model tables you defined and populated for Problem 3, explore your data in its new form.  Use any of the query strategies we've seen in class, including transformations, aggregates, subqueries, rollups, and, of course, joins.  Add plots to highlight particular themes that stand out.  Describe your thinking and observations along the way.

# %% [markdown]
# ### 1. Take a look of all dimensions and fact table.

# %%
# %%sql
# SELECT * FROM location
# LIMIT 5;
# Out:
# 5 rows affected.
# [(1, '4100 FLEETWOOD AVE', '4100 Fleetwood Av', '(39.3558990425, -76.5310915803)'),
#  (2, '2600 WEGWORTH LN', '2600 Wegworth Ln', '(39.2545661886, -76.6453235863)'),
#  (3, '2500 BROOKFIELD AVE', '2500 Brookfield Av', '(39.3157914808, -76.6338801822)'),
#  (4, '0', '2800  Argonne Dr', '0'),
#  (5, '200 WASHBURN AVE', '200 Washburn Av', '(39.2360039184, -76.6090551413)')]

# %%
# %%sql
# SELECT * FROM charge
# LIMIT 5;
# Out:
# 5 rows affected.
# [(1, '1 1106', 'CDS VIOLATION'),
#  (2, '3 0233', 'POSS W INT COCAINE'),
#  (3, '2A3550', 'Att-Cds Manuf/Dist. || Hgv/ Cds'),
#  (4, '5 3550', 'Cds:Poss Para || Cds Possess'),
#  (5, '0', 'Fugitive From Kansas')]

# %%
# %%sql
# SELECT * FROM district
# LIMIT 5;
# Out:
# 5 rows affected.
# [(1, 'Southern', 942, 'SPRING GARDEN INDUSTRIAL AREA'),
#  (2, 'Northern', 533, 'Hampden'),
#  (3, 'Southeastern', 232, 'Canton'),
#  (4, 'Southwestern', 814, 'FRANKLINTOWN ROAD'),
#  (5, 'Southwestern', 815, 'Lower Edmondson Village')]

# %%
# %%sql
# SELECT * FROM date
# LIMIT 5;
# Out:
# 5 rows affected.
# [(1, '2016', '03', '03', '1', '10:00'),
#  (2, '2015', '05', '30', '2', '02:39'),
#  (3, '2015', '02', '05', '1', '02:00'),
#  (4, '2013', '12', '23', '4', '21:35'),
#  (5, '2015', '07', '12', '3', '19:45')]

# %%
# %%sql
# SELECT * FROM criminal
# LIMIT 5;
# Out:
# 5 rows affected.
# [(35859, 7206, 41, 33458, 25, 'M', 'B'),
#  (9883, 5232, 1065, 58234, 24, 'M', 'B'),
#  (35859, 2868, 41, 49541, 25, 'F', 'W'),
#  (35859, 2868, 41, 64231, 29, 'M', 'B'),
#  (35859, 2868, 41, 17264, 26, 'M', 'B')]

# %% [markdown]
# ### 2. Find out which age groups will commit the most ferequent crimes

# %% [markdown]
# ### Find out the most ten frequent crimes

# %%
# %%sql
# SELECT charge.charge_description,COUNT(charge.charge_description) AS Frequency
# FROM criminal
# LEFT JOIN charge
# ON criminal.chargekey = charge.charge_key
# GROUP BY charge.charge_description
# ORDER BY Frequency DESC
# LIMIT 10;
# Out:
# 10 rows affected.
# [('Failure To Appear || Failure To Appear', 15373),
#  ('Asslt-Sec Degree || Assault-Sec Degree', 7769),
#  ('Unknown Charge', 7744),
#  ('Cds:Possess-Not Marihuana || Cds Violation', 5873),
#  ('Cds:Possess-Not Marihuana || Cds', 3760),
#  ('Violation Of Probation || Violation Of Probation', 3041),
#  ('Asslt-Sec Degree || Common Assault', 2805),
#  ('Cds: Poss Marihuana L/T 10 G || Cds Violation', 1633),
#  ('Asslt-Sec Degree || Assault', 1486),
#  ('Prostitution-General || Prostitution', 1431)]

# %% [markdown]
# ### Group the age
# We find that there are some 0 value of age variable, which we think it is not a maningful value because it is impossible that a new born baby will commit crimes. So we treate 0 as null value and will not group age equal to 0 to any age group.

# %%
# %%sql
# ALTER TABLE criminal
# ADD age_group VARCHAR(20);
# Out:
# Done.
# []

# %%
# %%sql
# UPDATE criminal
# SET age_group = '1-9'
# WHERE length(age::text) = 1
# AND age != 0
# Out:
# 0 rows affected.
# []

# %%
# %%sql
# UPDATE criminal
# SET age_group = '10-19'
# WHERE age::text like '1%';
# Out:
# 9345 rows affected.
# []

# %%
# %%sql
# UPDATE criminal
# SET age_group = '20-29'
# WHERE age::text like '2%';
# Out:
# 54049 rows affected.
# []

# %%
# %%sql
# UPDATE criminal
# SET age_group = '30-39'
# WHERE age::text like '3%';
# Out:
# 29919 rows affected.
# []

# %%
# %%sql
# UPDATE criminal
# SET age_group = '30-39'
# WHERE age::text like '3%';
# Out:
# 29919 rows affected.
# []

# %%
# %%sql
# UPDATE criminal
# SET age_group = '40-49'
# WHERE age::text like '4%';
# Out:
# 21368 rows affected.
# []

# %%
# %%sql
# UPDATE criminal
# SET age_group = '50-59'
# WHERE age::text like '5%';
# Out:
# 12746 rows affected.
# []

# %%
# %%sql
# UPDATE criminal
# SET age_group = '60-69'
# WHERE age::text like '6%';
# Out:
# 2146 rows affected.
# []

# %%
# %%sql
# UPDATE criminal
# SET age_group = '70-79'
# WHERE age::text like '7%';
# Out:
# 191 rows affected.
# []

# %%
# %%sql
# UPDATE criminal
# SET age_group = '80-89'
# WHERE age::text like '8%';
# Out:
# 13 rows affected.
# []

# %%
# %%sql
# UPDATE criminal
# SET age_group = '90-100'
# WHERE age::text like '9%'
# OR
# age = 100;
# Out:
# 2 rows affected.
# []

# %%
# %%sql
# SELECT * FROM criminal
# LIMIT 10
# Out:
# 10 rows affected.
# [(35859, 2868, 41, 17264, 26, 'M', 'B', '20-29'),
#  (18878, 5803, 41, 76390, 23, 'F', 'B', '20-29'),
#  (35859, 9502, 41, 12441, 47, 'M', 'B', '40-49'),
#  (35859, 9502, 41, 21577, 19, 'M', 'B', '10-19'),
#  (35859, 9216, 41, 19245, 39, 'M', 'B', '30-39'),
#  (35859, 9216, 41, 79533, 47, 'M', 'B', '40-49'),
#  (11311, 9502, 41, 30699, 52, 'M', 'B', '50-59'),
#  (27042, 11508, 41, 77394, 32, 'M', 'B', '30-39'),
#  (15673, 11508, 41, 77618, 31, 'M', 'B', '30-39'),
#  (35859, 9502, 41, 77258, 20, 'F', 'B', '20-29')]

# %% [markdown]
# ### Join criminal and charge to find which age groups  will commit the most ferequent crimes

# %%
# %%sql
# SELECT charge.charge_description, age_group, COUNT(charge_description) AS Frequency
# FROM criminal
# LEFT JOIN charge
# ON criminal.chargekey = charge.charge_key
# AND charge.charge_description = 'Failure To Appear || Failure To Appear'
# GROUP BY charge.charge_description, age_group
# ORDER BY Frequency DESC
# LIMIT 5;
# Out:
# 5 rows affected.
# [('Failure To Appear || Failure To Appear', '20-29', 6224),
#  ('Failure To Appear || Failure To Appear', '30-39', 3611),
#  ('Failure To Appear || Failure To Appear', '40-49', 2882),
#  ('Failure To Appear || Failure To Appear', '50-59', 1657),
#  ('Failure To Appear || Failure To Appear', '10-19', 665)]

# %%
# %matplotlib inline
result = _
result.bar()
# Out:
# <Container object of 5 artists>

# %%
# %%sql
# SELECT charge.charge_description, age_group, COUNT(charge_description) AS Frequency
# FROM criminal
# LEFT JOIN charge
# ON criminal.chargekey = charge.charge_key
# AND charge.charge_description = 'Asslt-Sec Degree || Assault-Sec Degree'
# GROUP BY charge.charge_description, age_group
# ORDER BY Frequency DESC
# LIMIT 5;
# Out:
# 5 rows affected.
# [('Asslt-Sec Degree || Assault-Sec Degree', '20-29', 3529),
#  ('Asslt-Sec Degree || Assault-Sec Degree', '30-39', 2045),
#  ('Asslt-Sec Degree || Assault-Sec Degree', '40-49', 1089),
#  ('Asslt-Sec Degree || Assault-Sec Degree', '50-59', 636),
#  ('Asslt-Sec Degree || Assault-Sec Degree', '10-19', 330)]

# %%
# %matplotlib inline
result = _
result.bar()
# Out:
# <Container object of 5 artists>

# %%
# %%sql
# SELECT charge.charge_description, age_group, COUNT(charge_description) AS Frequency
# FROM criminal
# LEFT JOIN charge
# ON criminal.chargekey = charge.charge_key
# AND charge.charge_description = 'Cds:Possess-Not Marihuana || Cds Violation'
# GROUP BY charge.charge_description, age_group
# ORDER BY Frequency DESC
# LIMIT 5;
# Out:
# 5 rows affected.
# [('Cds:Possess-Not Marihuana || Cds Violation', '20-29', 1746),
#  ('Cds:Possess-Not Marihuana || Cds Violation', '40-49', 1444),
#  ('Cds:Possess-Not Marihuana || Cds Violation', '50-59', 1096),
#  ('Cds:Possess-Not Marihuana || Cds Violation', '30-39', 1084),
#  ('Cds:Possess-Not Marihuana || Cds Violation', '10-19', 294)]

# %%
# %matplotlib inline
result = _
result.bar()
# Out:
# <Container object of 5 artists>

# %%
# %%sql
# SELECT charge.charge_description, age_group, COUNT(charge_description) AS Frequency
# FROM criminal
# LEFT JOIN charge
# ON criminal.chargekey = charge.charge_key
# AND charge.charge_description = 'Cds:Possess-Not Marihuana || Cds'
# GROUP BY charge.charge_description, age_group
# ORDER BY Frequency DESC
# LIMIT 5;
# Out:
# 5 rows affected.
# [('Cds:Possess-Not Marihuana || Cds', '20-29', 1246),
#  ('Cds:Possess-Not Marihuana || Cds', '40-49', 844),
#  ('Cds:Possess-Not Marihuana || Cds', '30-39', 747),
#  ('Cds:Possess-Not Marihuana || Cds', '50-59', 577),
#  ('Cds:Possess-Not Marihuana || Cds', '10-19', 225)]

# %%
# %matplotlib inline
result = _
result.bar()
# Out:
# <Container object of 5 artists>

# %%
# %%sql
# SELECT charge.charge_description, age_group, COUNT(charge_description) AS Frequency
# FROM criminal
# LEFT JOIN charge
# ON criminal.chargekey = charge.charge_key
# AND charge.charge_description = 'Violation Of Probation || Violation Of Probation'
# GROUP BY charge.charge_description, age_group
# ORDER BY Frequency DESC
# LIMIT 5;
# Out:
# 5 rows affected.
# [('Violation Of Probation || Violation Of Probation', '20-29', 1191),
#  ('Violation Of Probation || Violation Of Probation', '30-39', 682),
#  ('Violation Of Probation || Violation Of Probation', '40-49', 621),
#  ('Violation Of Probation || Violation Of Probation', '50-59', 336),
#  ('Violation Of Probation || Violation Of Probation', '10-19', 145)]

# %%
# %matplotlib inline
result = _
result.bar()
# Out:
# <Container object of 5 artists>

# %% [markdown]
# ### 2. Analyze average ages of top 10 crime types

# %%
# %%sql
# SELECT charge.charge_description, ROUND(AVG(criminal.age),2), COUNT(charge.charge_description)
# FROM criminal
# LEFT JOIN charge
# ON criminal.chargekey=charge.charge_key
# GROUP BY charge.charge_description
# ORDER BY COUNT(charge.charge_description) DESC
# LIMIT 10;
# Out:
# 10 rows affected.
# [('Failure To Appear || Failure To Appear', Decimal('34.11'), 15373),
#  ('Asslt-Sec Degree || Assault-Sec Degree', Decimal('32.55'), 7769),
#  ('Unknown Charge', Decimal('32.42'), 7744),
#  ('Cds:Possess-Not Marihuana || Cds Violation', Decimal('37.68'), 5873),
#  ('Cds:Possess-Not Marihuana || Cds', Decimal('36.17'), 3760),
#  ('Violation Of Probation || Violation Of Probation', Decimal('34.33'), 3041),
#  ('Asslt-Sec Degree || Common Assault', Decimal('32.81'), 2805),
#  ('Cds: Poss Marihuana L/T 10 G || Cds Violation', Decimal('28.36'), 1633),
#  ('Asslt-Sec Degree || Assault', Decimal('32.58'), 1486),
#  ('Prostitution-General || Prostitution', Decimal('34.76'), 1431)]

# %%
# %matplotlib inline
result = _
result.bar()
# Out:
# <Container object of 10 artists>

# %% [markdown]
# We assume the charge description can tell us thorough and detailed information about diffrent crime types. So we use charge description as crime type.
#
# From these pictures shown above, we can find that for top criminal types-"Failure To Appear", "Asslt-Sec Degree " and "Violation Of Probation ", the most frequent groups are 20-29, 30-39, 40-49 and 50-59. While for "Cds:Possess-Not Marihuana || Cds Violation" and "Cds:Possess-Not Marihuana || Cds Violation",pattern of the most frequent age groups have changed. Age group 40-49 and 50-59 bacome ahead of 30-39, although 20-29 is still the most frequent group.
#
# Also, we analyze the average age of top 10 frequently commited crimes. The averge ages are similar to each other related to top 10 crimes, from min=28 to max=37, which prove that among all age groups, 20-29 and 30-39 age groups have the largest criminals and also the most frequent age groups for different crime type.

# %% [markdown]
# ### 3. Analyze genders of top 10 crime types

# %%
# %%sql
# SELECT charge.charge_description, criminal.sex, COUNT(charge.charge_description)
# FROM criminal
# LEFT JOIN charge
# ON criminal.chargekey=charge.charge_key
# GROUP BY charge.charge_description, criminal.sex
# ORDER BY COUNT(charge.charge_description) DESC
# LIMIT 10;
# Out:
# 10 rows affected.
# [('Failure To Appear || Failure To Appear', 'M', 11553),
#  ('Unknown Charge', 'M', 6681),
#  ('Asslt-Sec Degree || Assault-Sec Degree', 'M', 6202),
#  ('Cds:Possess-Not Marihuana || Cds Violation', 'M', 4890),
#  ('Failure To Appear || Failure To Appear', 'F', 3820),
#  ('Cds:Possess-Not Marihuana || Cds', 'M', 3092),
#  ('Violation Of Probation || Violation Of Probation', 'M', 2274),
#  ('Asslt-Sec Degree || Common Assault', 'M', 2135),
#  ('Asslt-Sec Degree || Assault-Sec Degree', 'F', 1567),
#  ('Cds: Poss Marihuana L/T 10 G || Cds Violation', 'M', 1442)]

# %% [markdown]
# We can see from the picture, male crimes are much more than female overall. And for the same crime type, male crimes are still much more than female.

# %% [markdown]
# ### 4. Analyze top 10 districts/neighborhoods with most crimes and race in these districts/neighborhoods

# %%
# %%sql
# SELECT district.district, criminal.race, COUNT(district.district)
# FROM criminal
# LEFT JOIN district
# ON criminal.districtkey=district.district_key
# GROUP BY district.district, criminal.race
# ORDER BY COUNT(district.district) DESC
# LIMIT 10;
# Out:
# 10 rows affected.
# [('0', 'B', 41591),
#  ('Western', 'B', 9725),
#  ('Eastern', 'B', 9657),
#  ('0', 'W', 8914),
#  ('Central', 'B', 7671),
#  ('Northeastern', 'B', 7659),
#  ('Southern', 'B', 6887),
#  ('Northwestern', 'B', 6544),
#  ('Southwestern', 'B', 6037),
#  ('Southeastern', 'B', 5869)]

# %%
# %matplotlib inline
result = _
result.bar()
# Out:
# <Container object of 10 artists>

# %%
# %%sql
# SELECT district.neighborhood, criminal.race, COUNT(district.neighborhood)
# FROM criminal
# LEFT JOIN district
# ON criminal.districtkey=district.district_key
# GROUP BY district.neighborhood, criminal.race
# ORDER BY COUNT(district.neighborhood) DESC
# LIMIT 10;
# Out:
# 10 rows affected.
# [('0', 'B', 41598),
#  ('0', 'W', 8915),
#  ('DOWNTOWN', 'B', 2172),
#  ('SANDTOWN-WINCHESTER', 'B', 1660),
#  ('PENN NORTH', 'B', 1389),
#  ('BROADWAY EAST', 'B', 1379),
#  ('UPTON', 'B', 1067),
#  ('BELAIR-EDISON', 'B', 997),
#  ('CARROLLTON RIDGE', 'B', 976),
#  ('CENTRAL PARK HEIGHTS', 'B', 949)]

# %% [markdown]
# It is obvious that for majority districts and neighborhood, B race is the most frequent criminals.

# %% [markdown]
# ### 5. Analyze top 10 combination of crimes and races

# %%
# %%sql
# SELECT charge.charge_description, criminal.race, COUNT(criminal.race)
# FROM criminal
# LEFT JOIN charge
# ON criminal.districtkey=charge.charge_key
# GROUP BY charge.charge_description, criminal.race
# ORDER BY COUNT(criminal.race) DESC
# LIMIT 10;
# Out:
# 10 rows affected.
# [('Extortion:Value $500. Plus || Dest Of Property', 'B', 41590),
#  ('Extortion:Value $500. Plus || Dest Of Property', 'W', 8914),
#  ('Handgun In Vehicle || Handgun', 'B', 1142),
#  ('Extortion:Value $500. Plus || Dest Of Property', 'U', 926),
#  ('Cds: Possession-Marihuana || Possess Cds', 'B', 656),
#  ('Att-Sex Off Reg-Change Address || Att-Sex Off Reg-Fail', 'B', 642),
#  ('Cds:Possess-Not Marihuana || Cds- Heroin', 'B', 598),
#  ('Cds:Possess-Not Marihuana || Cds Poss Oxycodone', 'B', 591),
#  ('Cds Manuf/Dist-Narc || Dist  Cocaine', 'B', 590),
#  ('CDS', 'B', 532)]

# %% [markdown]
# ### 6. Analyze top crimes and genders in year 2016

# %%
# %%sql
# SELECT '2016' AS year, charge.charge_description, criminal.sex, COUNT(charge.charge_description)
# FROM criminal
# LEFT JOIN date
# ON criminal.datekey=date.date_key
# LEFT JOIN charge
# ON criminal.chargekey=charge.charge_key
# GROUP BY charge.charge_description, criminal.sex
# ORDER BY COUNT(charge.charge_description) DESC
# LIMIT 10;
# Out:
# 10 rows affected.
# [('2016', 'Failure To Appear || Failure To Appear', 'M', 11553),
#  ('2016', 'Unknown Charge', 'M', 6681),
#  ('2016', 'Asslt-Sec Degree || Assault-Sec Degree', 'M', 6202),
#  ('2016', 'Cds:Possess-Not Marihuana || Cds Violation', 'M', 4890),
#  ('2016', 'Failure To Appear || Failure To Appear', 'F', 3820),
#  ('2016', 'Cds:Possess-Not Marihuana || Cds', 'M', 3092),
#  ('2016', 'Violation Of Probation || Violation Of Probation', 'M', 2274),
#  ('2016', 'Asslt-Sec Degree || Common Assault', 'M', 2135),
#  ('2016', 'Asslt-Sec Degree || Assault-Sec Degree', 'F', 1567),
#  ('2016', 'Cds: Poss Marihuana L/T 10 G || Cds Violation', 'M', 1442)]

# %% [markdown]
# ### 7. Using rollup to see the frequency of combination of charge decription, sex and neighborhood

# %%
# %%sql
# SELECT '2015' AS year, charge.charge_description, criminal.sex, district.neighborhood, COUNT(charge.charge_description)
# FROM criminal
# LEFT JOIN date
# ON criminal.datekey=date.date_key
# LEFT JOIN charge
# ON criminal.chargekey=charge.charge_key
# LEFT JOIN district
# ON criminal.districtkey=district.district_key
# GROUP BY ROLLUP (charge.charge_description, criminal.sex, district.neighborhood)
# ORDER BY COUNT(charge.charge_description) DESC
# LIMIT 10;
# Out:
# 10 rows affected.
# [('2015', None, None, None, 129836),
#  ('2015', 'Failure To Appear || Failure To Appear', None, None, 15373),
#  ('2015', 'Failure To Appear || Failure To Appear', 'M', None, 11553),
#  ('2015', 'Failure To Appear || Failure To Appear', 'M', '0', 11541),
#  ('2015', 'Asslt-Sec Degree || Assault-Sec Degree', None, None, 7769),
#  ('2015', 'Unknown Charge', None, None, 7744),
#  ('2015', 'Unknown Charge', 'M', None, 6681),
#  ('2015', 'Asslt-Sec Degree || Assault-Sec Degree', 'M', None, 6202),
#  ('2015', 'Asslt-Sec Degree || Assault-Sec Degree', 'M', '0', 6196),
#  ('2015', 'Cds:Possess-Not Marihuana || Cds Violation', None, None, 5873)]

# %% [markdown]
# ### 7. Analyze realationship between hour and frequency of specific crime type

# %%
# %%sql
# SELECT date.hour, COUNT(charge.charge_description) AS Frequency
# FROM (criminal
#       LEFT JOIN date
#       ON criminal.datekey = date.date_key
#       LEFT JOIN charge
#       ON criminal.chargekey = charge.charge_key)
# WHERE charge.charge_description = 'Cds:Possess-Not Marihuana || Cds Violation'
# AND criminal.age_group = '20-29'
# GROUP BY date.hour
# ORDER BY Frequency DESC
# LIMIT 24;
# Out:
# 24 rows affected.
# [('20:00', 34),
#  ('13:00', 32),
#  ('21:00', 31),
#  ('18:30', 30),
#  ('11:00', 28),
#  ('19:00', 28),
#  ('15:00', 27),
#  ('12:00', 26),
#  ('11:30', 25),
#  ('17:00', 25),
#  ('12:30', 25),
#  ('19:30', 23),
#  ('14:00', 23),
#  ('21:30', 23),
#  ('17:30', 23),
#  ('18:00', 22),
#  ('13:30', 21),
#  ('16:30', 20),
#  ('14:30', 20),
#  ('16:00', 19),
#  ('10:30', 19),
#  ('12:15', 18),
#  ('20:30', 18),
#  ('10:00', 15)]

# %% [markdown]
# From studies above, we are interested in the crime type: Cds:Possess-Not Marihuana || Cds Violation because it shows a different criminal age group pattern. So we do a deep analyze to find if there are any relationships between it and the crime time. It turns out the frequent time is a day for this kind of crime happened in from 20:00 to 21:00. And it also happened heavily in afternoon. It is more less happened in the morning.

# %% [markdown]
# ## Bonus (10 points for one of A or B)
#
#
# ### Option A - Automating ETL
#
# Consider the work you did to load your original raw dataset and then transform it into a dimensional model for analysis.  What would it take to automate this process?  How often would you need to update the data?  Could you easily automate any data cleaning steps?  What checks would you need to put in place to ensure quality?  Would humans need to be involved, or could you automate it all?
#
# Discuss.
#
#
# ### Option B - Augmenting dimensions
#
# Considering your dimensional model, what external data could you find to augment it?  As in the case of bike trips, where weather might provide an interesting added dimension/context not present in the original data, you can probably find another source of data to complement your own model.  Identify one such source and add it to your model, demonstrating its value with a few new queries.

# %% [markdown]
# ### Option A - Automating ETL
#
# #### What would it take to automate this process?
#
# We already wrote many SQL scripts for ETL process. Automating these tests means we need to develop a solution to store these scripts, schedule the execution and automate the comparison of the outcome of the test scripts with the expected results. And this procedure can be stored to run again and again.
#
# We can start with the time data since every new record would have a new date column. So we build this procedure to check the newest dates and update other columns accordingly. After it updates and inserts new infomation, the scripts can finish the rest work: transform data into dimensional models.

# %% [markdown]
# #### How often would you need to update the data?
#
# I think the frequency of updating data depends on the industry. Considering the data we analyze is crime records, I think it's reasonable that we update it everyday, since we can see many records happen in same days.

# %% [markdown]
# #### Could you easily automate any data cleaning steps?
#
# Similar to previous automating procedure, I believe we can easily automate the cleaning steps by creating a stored procedure to check null values in new records and deal with it like we did before.

# %% [markdown]
# #### What checks would you need to put in place to ensure quality?
#
# The automating procedure could work fine in updating and cleaning data. But we still need to make efforts in solving other potential problems. First we need to create and store scripts to make sure there's no duplicate records being inserted, which means checking if 2 records are exactly same and delete one of them. Or we can set a process reporting duplicates before deleting them.
# Second we need to create another procedure to handle data exception. For example when data is unresonablely big or small, or too many mulls in one record. So this procedure identify exceptions and report them.

# %% [markdown]
# #### Would humans need to be involved, or could you automate it all?
#
# I think humans need to be involved like when data exceptions or duplicates emerge and people need to decide cope strategies instead of letting scripts automating it all.

# %% [markdown]
# ### collaboration

# %% [markdown]
# Collaborators:
# Yunning Zhu
# Jingning Li
#
# We both participated in all parts of this projects. It is kind of perfect half-half work. For example, for part III, Yunning found out ways to connect keys in dimension tables to fact tabels and Jingning handle all null values to make sure all transcation in fact table can have a key.
#
# We try our best to figure out problems when we enconter them and help each other solving problems. We feel good in this collaboration.
